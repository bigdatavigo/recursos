# %%
import requests
#url="https://www.idealista.com/venta-viviendas/cartagena/cartagena/casco-antiguo/"
#respuesta=requests.get(url)

# %%
contenido="""
<!DOCTYPE html>
<!--[if IE 8]><html class="ie8" lang="es" env="es" username=""><![endif]--> <!--[if IE 9]><html class="ie9" lang="es" env="es" username=""><![endif]--> <!--[if gt IE 9]><!--> <html lang="es" env="es" username="" data-userAuth="false"><!--<![endif]--> <head> <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"> <title>Casas y pisos en Casco Antiguo, Cartagena &#8212; idealista</title> <meta http-equiv="Content-Type" content="text/html; charset=UTF-8"> <meta name="description" content="201 casas y pisos en Casco Antiguo, Cartagena, a partir de 25.000 euros de particulares e inmobiliarias. casas y pisos en Casco Antiguo, Cartagena: anuncios de particular a particular y de agencias inmobiliarias."> <meta name="author" content="idealista.com"> <meta http-equiv="cleartype" content="on"> <meta name="pragma" content="no-cache"/> <meta http-equiv="Pragma" content="no-cache"/> <meta http-equiv="Expires" content="Fri, 01 Jan 1990 00:00:00 GMT"/> <meta http-equiv="Cache-Control" content="no-cache, no-store, must-revalidate"/> <link rel="shortcut icon" href="/favicon.ico"> <link rel="apple-touch-icon" href="https://st1.idealista.com/static/common/icons/60x60.png?20180704154217"> <link rel="apple-touch-icon-precomposed" href="https://st1.idealista.com/static/common/icons/60x60.png?20180704154217"> <link rel="apple-touch-icon" sizes="76x76" href="https://st1.idealista.com/static/common/icons/76x76.png?20180704154217"> <link rel="apple-touch-icon-precomposed" sizes="76x76" href="https://st1.idealista.com/static/common/icons/76x76.png?20180704154217"> <link rel="apple-touch-icon" sizes="120x120" href="https://st1.idealista.com/static/common/icons/120x120.png?20180704154217"> <link rel="apple-touch-icon-precomposed" sizes="120x120" href="https://st1.idealista.com/static/common/icons/120x120.png?20180704154217"> <link rel="apple-touch-icon" sizes="152x152" href="https://st1.idealista.com/static/common/icons/152x152.png?20180704154217"> <link rel="apple-touch-icon-precomposed" sizes="152x152" href="https://st1.idealista.com/static/common/icons/152x152.png?20180704154217"> <meta name="apple-itunes-app" content="app-id=465958311"/> <meta name="google-play-app" content="app-id=com.idealista.android"/> <meta name="app-download-url" content="/download"/> <!--[if lte IE 8]><script src="https://st1.idealista.com/static/common/release/modules/ie8.js?20180704154217"></script><![endif]--> <!--[if lte IE 9]><script src="https://st1.idealista.com/static/common/release/modules/ie9.js?20180704154217"></script><![endif]--> <link rel="stylesheet" href="https://st1.idealista.com/static/common/release/listing/listing.css?20180704154217" type="text/css"/> <link rel="canonical" href="https://www.idealista.com/venta-viviendas/cartagena/cartagena/casco-antiguo/"/> <meta name="ROBOTS" content="NOODP,INDEX, FOLLOW"/> <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=2.0, minimum-scale=1.0"> <script src='//ec-ns.sascdn.com/diff/js/smart.js' type="text/javascript" async></script> <script type="text/javascript">
                        var sas = sas || {};
                        sas.cmd = sas.cmd || [];
                        sas.cmd.push(function() {
                            sas.setup({domain: '//smart.idealista.com', async: true, renderMode: 2});
                        });
                    </script> <script>
                        sas.cmd.push(function() {
                            sas.call('onecall', {
                                siteId:	33114,
                                pageId:	253245,
                                formatId: '16022',
                                target: 'geo=0-EU-ES-30-02-001-016-04-002-XX-XX;ope=s;geoc=0-EU-ES-30-02;auth=f;typ=hs;geop=0-EU-ES-30'
                            }, {
                                onNoad: function(data){
                                    if (data.formatId) {
                                        var bannerDiv = document.getElementById('banners_' + data.formatId);
                                        if (bannerDiv != null) {
                                            bannerDiv.style.display = 'none';
                                        }
                                    }
                                }
                            });
                        });
                    </script> <link rel="alternate" hreflang="ca" href="https://www.idealista.com/ca/venta-viviendas/cartagena/cartagena/casco-antiguo/"/><link rel="alternate" hreflang="en" href="https://www.idealista.com/en/venta-viviendas/cartagena/cartagena/casco-antiguo/"/><link rel="alternate" hreflang="fr" href="https://www.idealista.com/fr/venta-viviendas/cartagena/cartagena/casco-antiguo/"/><link rel="alternate" hreflang="de" href="https://www.idealista.com/de/venta-viviendas/cartagena/cartagena/casco-antiguo/"/><link rel="alternate" hreflang="it" href="https://www.idealista.com/it/venta-viviendas/cartagena/cartagena/casco-antiguo/"/><link rel="alternate" hreflang="pt" href="https://www.idealista.com/pt/venta-viviendas/cartagena/cartagena/casco-antiguo/"/> <link rel="next" href="/venta-viviendas/cartagena/cartagena/casco-antiguo/"/> </head> <body id=""> <header id="main-header" class=" help-center ide-header"> <div class="col-ide-lg-12 col-ide-xl-12 content"> <figure class="logo-container"> <a href='/' class='id-logo'> <span class='icon-idealista-icon id-brand'></span></a> </figure> <nav> <div class="lang-selector"> <span class="lang-selector--lang-selected icon-arrow-dropdown"> <span class="flag lang-es"></span> Español </span> <ul class="lang-selector--lang-options"> <li> <a rel="nofollow" id="idioma-ca" href="/ca/venta-viviendas/cartagena/cartagena/casco-antiguo/" data-xiti-shared-n2="true" data-xiti-navigation="cambio::idioma::cabecera::ca"> <span> <span class="flag lang-ca"></span>Català </span> </a> </li> <li> <a rel="nofollow" id="idioma-en" href="/en/venta-viviendas/cartagena/cartagena/casco-antiguo/" data-xiti-shared-n2="true" data-xiti-navigation="cambio::idioma::cabecera::en"> <span> <span class="flag lang-en"></span>English </span> </a> </li> <li> <a rel="nofollow" id="idioma-fr" href="/fr/venta-viviendas/cartagena/cartagena/casco-antiguo/" data-xiti-shared-n2="true" data-xiti-navigation="cambio::idioma::cabecera::fr"> <span> <span class="flag lang-fr"></span>Français </span> </a> </li> <li> <a rel="nofollow" id="idioma-de" href="/de/venta-viviendas/cartagena/cartagena/casco-antiguo/" data-xiti-shared-n2="true" data-xiti-navigation="cambio::idioma::cabecera::de"> <span> <span class="flag lang-de"></span>Deutsch </span> </a> </li> <li> <a rel="nofollow" id="idioma-it" href="/it/venta-viviendas/cartagena/cartagena/casco-antiguo/" data-xiti-shared-n2="true" data-xiti-navigation="cambio::idioma::cabecera::it"> <span> <span class="flag lang-it"></span>Italiano </span> </a> </li> <li> <a rel="nofollow" id="idioma-pt" href="/pt/venta-viviendas/cartagena/cartagena/casco-antiguo/" data-xiti-shared-n2="true" data-xiti-navigation="cambio::idioma::cabecera::pt"> <span> <span class="flag lang-pt"></span>Português </span> </a> </li> <li class="separator"> <a href="http://www.idealista.it/es/" title="" data-xiti-shared-n2="true" data-xiti-navigation="cambio::pais::cabecera::it">idealista.it</a> </li> <li> <a href="http://www.idealista.pt/es/" title="" data-xiti-shared-n2="true" data-xiti-navigation="cambio::pais::cabecera::pt">idealista.pt</a> </li> </ul> </div> <ul class="no-logged-user-menu ide-main-menu" id="no-login-user-bar"> <li id="put-adv-free" class="ide-main-menu__adv-free"> <a data-xiti-markup='{ "click": {"xtPage":"header::new-advert","xtn2":"114","mustXtn2":false,"actionType":"CLICK"} }' href="/info/publicar-anuncio"> <span class="icon-pin"> Pon tu anuncio gratis </span> </a> </li> <li id="your-account"> <a data-xiti-markup='{ "click": {"xtPage":"header::login","xtn2":"114","mustXtn2":false,"actionType":"CLICK"} }' href="/login" rel="nofollow" class="icon-user-no-logged"> Acceso<span class="hide-txt"> usuarios</span> </a> </li> </ul> </nav> </div> </header> <div id="wrapper"> <div id="main" data-isLogged="false"> <div class="container"> <div class="full-width-background"> <div class="breadcrumb-geo wrapper clearfix"> <ul class=""> <li> <a href="/">idealista</a> </li> <li class=""> <a href="/venta-viviendas/murcia-provincia/mapa">Murcia provincia</a> <span class="breadcrumb-info">25.749</span> </li> <li class=""> <a href="/venta-viviendas/murcia/campo-de-cartagena/mapa">Campo de Cartagena </a> <span class="breadcrumb-info">4.383</span> </li> <li class=""> <a href="/venta-viviendas/cartagena-murcia/mapa">Cartagena </a> <span class="breadcrumb-info">3.537</span> </li> <li class=""> <a href="/venta-viviendas/cartagena/cartagena/mapa">Cartagena </a> <span class="breadcrumb-info">1.404</span> </li> <li class="current-level"> <span class="breadcrumb-title icon-arrow-dropdown-after">Casco Antiguo </span> <div class="breadcrumb-subitems"> <ul> <li> <a href="/venta-viviendas/cartagena/cartagena/alameda/" title="Alameda" data-location-id="0-EU-ES-30-02-001-016-04-003">Alameda</a> <span class="sidenote"></span> </li> <li> <strong>Casco Antiguo</strong> <ul> </ul> </li> <li> <a href="/venta-viviendas/cartagena/cartagena/ciudad-jardin/" title="Ciudad Jardín" data-location-id="0-EU-ES-30-02-001-016-04-009">Ciudad Jardín</a> <span class="sidenote"></span> </li> <li> <a href="/venta-viviendas/cartagena/cartagena/ensanche/" title="Ensanche" data-location-id="0-EU-ES-30-02-001-016-04-010">Ensanche</a> <span class="sidenote"></span> </li> <li> <a href="/venta-viviendas/cartagena/cartagena/la-concepcion/" title="La Concepción" data-location-id="0-EU-ES-30-02-001-016-04-004">La Concepción</a> <span class="sidenote"></span> </li> <li> <a href="/venta-viviendas/cartagena/cartagena/los-barreros-cuatro-santos/" title="Los Barreros-Cuatro Santos" data-location-id="0-EU-ES-30-02-001-016-04-005">Los Barreros-Cuatro Santos</a> <span class="sidenote"></span> </li> <li> <a href="/venta-viviendas/cartagena/cartagena/peral-la-vereda/" title="Peral-La Vereda" data-location-id="0-EU-ES-30-02-001-016-04-001">Peral-La Vereda</a> <span class="sidenote"></span> </li> <li> <a href="/venta-viviendas/cartagena/cartagena/san-anton/" title="San Antón" data-location-id="0-EU-ES-30-02-001-016-04-006">San Antón</a> <span class="sidenote"></span> </li> <li> <a href="/venta-viviendas/cartagena/cartagena/san-gines-virgen-de-la-caridad/" title="San Ginés-Virgen de la Caridad" data-location-id="0-EU-ES-30-02-001-016-04-007">San Ginés-Virgen de la Caridad</a> <span class="sidenote"></span> </li> <li> <a href="/venta-viviendas/cartagena/cartagena/santa-lucia/" title="Santa Lucía" data-location-id="0-EU-ES-30-02-001-016-04-008">Santa Lucía</a> <span class="sidenote"></span> </li> </ul> </div> <span class="breadcrumb-info">201</span> </li> </ul> </div> <div class="wrapper clearfix"> <div id="h1-container"> <span class="h1-simulated">201 </span> <h1>casas y pisos en Casco Antiguo, Cartagena</h1> </div> </div> <div id="fixed-toolbar"> <div class="fixed-toolbar-controls"> <button id="fixed-toolbar-filter" class="icon-filter toolbar-button fake-anchor">Filtrar</button> <a id="toolbar-listing-link" href="/venta-viviendas/cartagena/cartagena/casco-antiguo/" title="Listado" class="toolbar-button icon-list" data-filter-href="listingSearchUrl">Listado</a> <a id="toolbar-map-link" href="/venta-viviendas/cartagena/cartagena/casco-antiguo/mapa-google" title="Mapa" class="toolbar-button icon-location" data-filter-href="mapSearchUrl">Mapa</a> </div> <div class="favs-only"> <span class="favs-only-nofavs feedback contextual warning no-background icon-feedbk-alert d-none"> Ningún favorito por ahora </span> <label class="input-switch"> <input name="checkbox" type="checkbox" data-key="onlySavedAds"> <span></span> <span> Solo favoritos </span> </label> </div> <div class="save-search-container"> <p class="txt-soft txt-caption">Nuevos anuncios en tu email:</p> <input class="saveSearchSubmit btn action expand" type="submit" value="Guardar búsqueda" data-summaryurl="/recibir-alertas-gratis-primer-resumen/23" data-suggestedsummaryurl="/recibir-alertas-gratis-primer-resumen/24" data-saveurl="/savealert.ajax/19" data-saverelatedurl="/ajax/save-related-alert-popup.ajax/28" data-emailverifyurl="/ajax/alerts-ls-existence-and-active/17" data-forgotpasswordurl="/recordar-password" data-didntgetmailurl="/info/info-problema-email"/> <input type="hidden" name="savingAlertStartingPoint" value=""> </div> </div> <div class="wrapper clearfix"> <div class="header-bottom clearfix"> <div class="second-level-menu operation-menu" id="operation"> <ul> <li class="actived"> <span>Comprar</span> </li> <li> <a href="/alquiler-viviendas/cartagena/cartagena/casco-antiguo/" rel="nofollow" data-filter-href="rentListingSearchUrl"> <span>Alquilar</span> </a> </li> </ul> </div> <div class="favs-only"> <span class="favs-only-nofavs feedback contextual warning no-background icon-feedbk-alert d-none"> Ningún favorito por ahora </span> <label class="input-switch"> <input name="checkbox" type="checkbox" data-key="onlySavedAds"> <span></span> <span> Solo favoritos </span> </label> </div> </div> </div> </div> <div id="content-wrapper" class="wrapper clearfix"> <div id="aside-fixed-toolbar" class="clearfix"> <span id="device-filters-total"> <span>201</span> resultados </span> <a href="#" id="device-filters-see-results" class="btn action smaller d-none">&nbsp;</a> <a href="#" class="icon-close" id="device-filters-close"></a> <a href="#" id="device-filters-cancel" class="d-none">Cancelar</a> </div> <aside> <div class="save-search-box "> <p class="txt-soft txt-caption">Nuevos anuncios en tu email:</p> <input class="saveSearchSubmit btn action expand" type="submit" value="Guardar búsqueda" data-summaryurl="/recibir-alertas-gratis-primer-resumen/23" data-suggestedsummaryurl="/recibir-alertas-gratis-primer-resumen/24" data-saveurl="/savealert.ajax/19" data-saverelatedurl="/ajax/save-related-alert-popup.ajax/28" data-emailverifyurl="/ajax/alerts-ls-existence-and-active/17" data-forgotpasswordurl="/recordar-password" data-didntgetmailurl="/info/info-problema-email"/> <input type="hidden" name="savingAlertStartingPoint" value=""> </div> <div class="live-search-save d-none"> <p> **some title<p> <p> **some explaining text<p> <button class="btn action save-live-search"> **Vale, guardar</button> <a class="btn cancel"> **Cancelar</a> </div> <div id="aside-filters"> <form id="filter-form"> <input type="hidden" name="freeText" value="" class="modify-filter"/> <div class="item-form" id="change-operation-mobile-container"> <span>Qué buscas</span> <p> <span>Comprar, casas y pisos</span> <a id="change-operation-btn" href="#">Cambiar</a> </p> </div> <div class="item-form" id="typology-filter-container"> <span>Qué buscas</span> <input type="hidden" name="typology" value="1"> <ul class="dropdown-list-refresh"> <li data-value="10" data-href="/venta-obranueva/cartagena/cartagena/casco-antiguo/"> <a href="/venta-obranueva/cartagena/cartagena/casco-antiguo/" title="Obra nueva" data-filter-href="newdevelopment">Obra nueva</a> </li> <li data-value="1">Viviendas</li> <li data-value="5" data-href="/venta-oficinas/cartagena/cartagena/casco-antiguo/"> <a href="/venta-oficinas/cartagena/cartagena/casco-antiguo/" title="Oficinas" data-filter-href="office">Oficinas</a> </li> <li data-value="6" data-href="/venta-locales/cartagena/cartagena/casco-antiguo/"> <a href="/venta-locales/cartagena/cartagena/casco-antiguo/" title="Locales o naves" data-filter-href="warehouse">Locales o naves</a> </li> <li data-value="4" data-href="/venta-garajes/cartagena/cartagena/casco-antiguo/"> <a href="/venta-garajes/cartagena/cartagena/casco-antiguo/" title="Garajes" data-filter-href="garage">Garajes</a> </li> <li data-value="8" data-href="/venta-terrenos/cartagena/cartagena/casco-antiguo/"> <a href="/venta-terrenos/cartagena/cartagena/casco-antiguo/" title="Terrenos" data-filter-href="land">Terrenos</a> </li> <li data-value="12" data-href="/venta-trasteros/cartagena/cartagena/casco-antiguo/"> <a href="/venta-trasteros/cartagena/cartagena/casco-antiguo/" title="Trasteros" data-filter-href="storageroom">Trasteros</a> </li> <li data-value="13" data-href="/venta-edificios/cartagena/cartagena/casco-antiguo/"> <a href="/venta-edificios/cartagena/cartagena/casco-antiguo/" title="Edificios" data-filter-href="building">Edificios</a> </li> </ul> </div> <div id="price-filter-container" class="item-form multiple"> <span>Precio</span> <div class='dropdown-list'><input type='hidden' name='adfilter_pricemin' value=''/><ul class="dropdown-list dropdown-insertion" data-confirm="Ok" data-title="Mín" data-maxlength="14" data-placeholder="Otro" data-rangerole="min"><li data-value="default"><a href="#">Mín</a></li> <li data-value="60000"><a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/con-precio-desde_60000/">60.000</a></li> <li data-value="80000"><a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/con-precio-desde_80000/">80.000</a></li> <li data-value="100000"><a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/con-precio-desde_100000/">100.000</a></li> <li data-value="120000"><a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/con-precio-desde_120000/">120.000</a></li> <li data-value="140000"><a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/con-precio-desde_140000/">140.000</a></li> <li data-value="150000"><a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/con-precio-desde_150000/">150.000</a></li> <li data-value="160000"><a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/con-precio-desde_160000/">160.000</a></li> <li data-value="180000"><a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/con-precio-desde_180000/">180.000</a></li> <li data-value="200000"><a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/con-precio-desde_200000/">200.000</a></li> <li data-value="220000"><a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/con-precio-desde_220000/">220.000</a></li> <li data-value="240000"><a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/con-precio-desde_240000/">240.000</a></li> <li data-value="260000"><a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/con-precio-desde_260000/">260.000</a></li> <li data-value="280000"><a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/con-precio-desde_280000/">280.000</a></li> <li data-value="300000"><a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/con-precio-desde
><a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/con-metros-cuadrados-menos-de_40/">40 m²</a></li> <li data-value="60"><a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/con-metros-cuadrados-menos-de_60/">60 m²</a></li> <li data-value="80"><a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/con-metros-cuadrados-menos-de_80/">80 m²</a></li> <li data-value="100"><a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/con-metros-cuadrados-menos-de_100/">100 m²</a></li> <li data-value="120"><a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/con-metros-cuadrados-menos-de_120/">120 m²</a></li> <li data-value="140"><a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/con-metros-cuadrados-menos-de_140/">140 m²</a></li> <li data-value="160"><a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/con-metros-cuadrados-menos-de_160/">160 m²</a></li> <li data-value="180"><a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/con-metros-cuadrados-menos-de_180/">180 m²</a></li> <li data-value="200"><a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/con-metros-cuadrados-menos-de_200/">200 m²</a></li> <li data-value="250"><a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/con-metros-cuadrados-menos-de_250/">250 m²</a></li> <li data-value="300"><a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/con-metros-cuadrados-menos-de_300/">300 m²</a></li> <li data-value="350"><a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/con-metros-cuadrados-menos-de_350/">350 m²</a></li> <li data-value="400"><a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/con-metros-cuadrados-menos-de_400/">400 m²</a></li> <li data-value="450"><a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/con-metros-cuadrados-menos-de_450/">450 m²</a></li> <li data-value="500"><a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/con-metros-cuadrados-menos-de_500/">500 m²</a></li> <li data-value="600"><a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/con-metros-cuadrados-menos-de_600/">600 m²</a></li> <li data-value="700"><a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/con-metros-cuadrados-menos-de_700/">700 m²</a></li> <li data-value="800"><a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/con-metros-cuadrados-menos-de_800/">800 m²</a></li> <li data-value="900"><a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/con-metros-cuadrados-menos-de_900/">900 m²</a></li> <li data-value="nolimit"><a href="#">Sin límite</a></li> </ul> </div> </div> <div class="item-form"> <span>Tipo de vivienda</span> <ul> <li> <label class='input-checkbox'> <input type="checkbox" name="adfilter_homes" id="homes" value="1"/><span><span><a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/con-pisos/">Pisos</a> </span></span></label> </li> <li> <label class='input-checkbox'> <input type="checkbox" name="adfilter_chalets" id="chalets" value="2"/><span><span><a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/con-chalets/">Casas o chalets</a> </span></span></label> </li> <li> <label class='input-checkbox'> <input type="checkbox" name="adfilter_countryhouses" id="countryhouses" value="3"/><span><span><a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/con-casas-de-pueblo/">Casas rústicas</a> </span></span></label> </li> <li> <label class='input-checkbox'> <input type="checkbox" name="adfilter_duplex" id="duplex" value="1"/><span><span><a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/con-duplex/">Dúplex</a> </span></span></label> </li> <li> <label class='input-checkbox'> <input type="checkbox" name="adfilter_penthouse" id="penthouse" value="1"/><span><span><a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/con-aticos/">Áticos</a> </span></span></label> </li> </ul> </div> <div class="item-form"> <span>Habitaciones</span> <ul> <li> <label class='input-checkbox'> <input type="checkbox" name="adfilter_rooms_0" id="rooms_0" value="0"/><span><span><a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/con-estudios/">0 habitaciones (estudios)</a> </span></span></label> </li> <li> <label class='input-checkbox'> <input type="checkbox" name="adfilter_rooms_1" id="rooms_1" value="1"/><span><span><a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/con-de-un-dormitorio/">1</a> </span></span></label> </li> <li> <label class='input-checkbox'> <input type="checkbox" name="adfilter_rooms_2" id="rooms_2" value="2"/><span><span><a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/con-de-dos-dormitorios/">2</a> </span></span></label> </li> <li> <label class='input-checkbox'> <input type="checkbox" name="adfilter_rooms_3" id="rooms_3" value="3"/><span><span><a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/con-de-tres-dormitorios/">3</a> </span></span></label> </li> <li> <label class='input-checkbox'> <input type="checkbox" name="adfilter_rooms_4_more" id="rooms_4_more" value="4"/><span><span><a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/con-de-cuatro-cinco-habitaciones-o-mas/">4 habitaciones o más</a> </span></span></label> </li> </ul> </div> <div class="item-form inline"> <span>Baños</span> <ul> <li> <label class='input-checkbox'> <input type="checkbox" name="adfilter_baths_1" id="baths_1" value="1"/><span><span><a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/con-un-bano/">1</a> </span></span></label> </li> <li> <label class='input-checkbox'> <input type="checkbox" name="adfilter_baths_2" id="baths_2" value="2"/><span><span><a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/con-dos-banos/">2</a> </span></span></label> </li> <li> <label class='input-checkbox'> <input type="checkbox" name="adfilter_baths_3" id="baths_3" value="3"/><span><span><a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/con-tres-banos-o-mas/">3 o +</a> </span></span></label> </li> </div> <div class="item-form"> <span>Estado</span> <ul> <li> <label class='input-checkbox'> <input type="checkbox" name="adfilter_newconstruction" id="newconstruction" value="1"/><span><span><a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/con-obra-nueva/">Obra nueva</a> </span></span></label> </li> <li> <label class='input-checkbox'> <input type="checkbox" name="adfilter_goodcondition" id="goodcondition" value="3"/><span><span><a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/con-buen-estado/">Buen estado</a> </span></span></label> </li> <li> <label class='input-checkbox'> <input type="checkbox" name="adfilter_toberestored" id="toberestored" value="2"/><span><span><a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/con-para-reformar/">A reformar</a> </span></span></label> </li> </ul> </div> <div class="item-form"> <span>Características</span> <ul> <li> <label class='input-checkbox'> <input type="checkbox" name="adfilter_hasairconditioning" id="hasairconditioning" value="1"/><span><span><a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/con-aireacondicionado/">Aire acondicionado</a> </span></span></label> </li> <li> <label class='input-checkbox'> <input type="checkbox" name="adfilter_wardrobes" id="wardrobes" value="1"/><span><span><a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/con-armarios-empotrados/">Armarios empotrados</a> </span></span></label> </li> <li> <label class='input-checkbox'> <input type="checkbox" name="adfilter_lift" id="lift" value="1"/><span><span><a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/con-ascensor/">Ascensor</a> </span></span></label> </li> <li> <label class='input-checkbox'> <input type="checkbox" name="adfilter_flatlocation" id="flatlocation" value="1"/><span><span><a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/con-exterior/">Exterior</a> </span></span></label> </li> <li> <label class='input-checkbox'> <input type="checkbox" name="adfilter_parkingspace" id="parkingspace" value="1"/><span><span><a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/con-garaje/">Garaje</a> </span></span></label> </li> <li> <label class='input-checkbox'> <input type="checkbox" name="adfilter_garden" id="garden" value="1"/><span><span><a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/con-jardin/">Jardín</a> </span></span></label> </li> <li> <label class='input-checkbox'> <input type="checkbox" name="adfilter_swimmingpool" id="swimmingpool" value="1"/><span><span><a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/con-piscina/">Piscina</a> </span></span></label> </li> <li> <label class='input-checkbox'> <input type="checkbox" name="adfilter_hasterrace" id="hasterrace" value="1"/><span><span><a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/con-terraza/">Terraza</a> </span></span></label> </li> <li> <label class='input-checkbox'> <input type="checkbox" name="adfilter_boxroom" id="boxroom" value="1"/><span><span><a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/con-trastero/">Trastero</a> </span></span></label> </li> </ul> </div> <div class="item-form"> <span>Planta</span> <ul> <li> <label class='input-checkbox'> <input type="checkbox" name="adfilter_top_floor" id="top_floor" value="1"/><span><span>Última planta </span></span></label> </li> <li> <label class='input-checkbox'> <input type="checkbox" name="adfilter_intermediate_floor" id="intermediate_floor" value="2"/><span><span>Plantas intermedias </span></span></label> </li> <li> <label class='input-checkbox'> <input type="checkbox" name="adfilter_ground_floor" id="ground_floor" value="3"/><span><span><a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/con-solo-bajos/">Bajos</a> </span></span></label> </li> </ul> </div> <div class="item-form"> <span>Tipo de anuncio</span> <ul> <li> <label class='input-checkbox'> <input type="checkbox" name="adfilter_agencyisabank" id="agencyisabank" value="1"/><span><span><a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/con-de-bancos/">De bancos</a> </span></span></label> </li> </ul> </div> <div class="item-form"> <span> Fecha de publicación </span> <ul><li><label class='input-radio'> <input type="radio" value="default" name="adfilter_published" checked="checked"/><span><span>Indiferente</span></span></label></li><li><label class='input-radio'> <input type="radio" value="1" name="adfilter_published"/><span><span>Últimas 48 horas</span></span></label></li><li><label class='input-radio'> <input type="radio" value="2" name="adfilter_published"/><span><span>La última semana</span></span></label></li><li><label class='input-radio'> <input type="radio" value="3" name="adfilter_published"/><span><span>El último mes</span></span></label></li></ul> </div> </form> <div class="item-form" id="favs-mobile-container"> <span>Favoritos</span> <div class="favs-only"> <span class="favs-only-nofavs feedback contextual warning no-background icon-feedbk-alert d-none"> Ningún favorito por ahora </span> <label class="input-switch"> <input name="checkbox" type="checkbox" data-key="onlySavedAds"> <span></span> <span> Solo favoritos </span> </label> </div> </div> <button id="reset-filters" class="icn-sg icon-undo fake-anchor fake-anchor-block" title="Quitar todos los filtros"> <span>Quitar todos los filtros</span> </button> </div> </aside> <div id="main-content"> <div id="top-filters"> <div id="view-type-buttons-content" class="clearfix"> <ul class="segmented-btn-group clearfix"> <li> <span id="listing-view-button" class="btn regular smaller icon-list selected"> Listado </span> </li> <li> <a id="map-view-button" href="/venta-viviendas/cartagena/cartagena/casco-antiguo/mapa-google" title="Mapa" class="btn regular smaller icon-location" data-filter-href="mapSearchUrl">Mapa</a> </li> </ul> <div id="order-by" data-param="ordenado-por"> <span class="order-by-label">Ordenar:</span> <ul id="view-type-toolbar-buttons" class="segmented-btn-group clearfix"> <li> <span data-value="" class="btn regular smaller selected" data-xiti-page="listado::ordenar::relevancia" data-xiti-shared-n2="true"> Relevancia </span> </li> <li> <a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/?ordenado-por=precio-asc" data-value="precio-asc" data-xiti-page="listado::ordenar::baratos" data-xiti-shared-n2="true" class="btn regular smaller"> Baratos </a> </li> <li> <a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/?ordenado-por=fecha-publicacion-desc" rel='nofollow' data-value="fecha-publicacion-desc" data-xiti-page="listado::ordenar::nuevos" data-xiti-shared-n2="true" class="btn regular smaller"> Recientes </a> </li> <li class="dropdown-menu"> <a href="#" title="Más" class="btn regular smaller icon-arrow-dropdown-after drop-button"><span>Más</span></a> <ul> <li> <span data-value="" class="selected"> Relevancia </span> </li> <li> <a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/?ordenado-por=precio-asc" data-value="precio-asc" class="" data-xiti-page="listado::ordenar::baratos" data-xiti-shared-n2="true"> Baratos </a> </li> <li> <a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/?ordenado-por=precio-desc" data-value="precio-desc" class="" data-xiti-page="listado::ordenar::lujo" data-xiti-shared-n2="true"> De lujo </a> </li> <li> <a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/?ordenado-por=fecha-publicacion-desc" data-value="fecha-publicacion-desc" rel='nofollow' class="" data-xiti-page="listado::ordenar::nuevos" data-xiti-shared-n2="true"> Recientes </a> </li> <li> <a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/?ordenado-por=fecha-publicacion-asc" data-value="fecha-publicacion-asc" class="" rel='nofollow' data-xiti-page="listado::ordenar::antiguos" data-xiti-shared-n2="true"> Antiguos </a> </li> <li> <a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/?ordenado-por=rebajas-desc" data-value="rebajas-desc" class="" data-xiti-page="listado::ordenar::bajaprecio-mas" data-xiti-shared-n2="true"> Han bajado más </a> </li> <li> <a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/?ordenado-por=precio-metro-cuadrado-asc" data-value="precio-metro-cuadrado-asc" class="" data-xiti-page="listado::ordenar::baratos-eurm2" data-xiti-shared-n2="true"> Baratos eur/m&sup2; </a> </li> <li> <a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/?ordenado-por=precio-metro-cuadrado-desc" data-value="precio-metro-cuadrado-desc" class="" data-xiti-page="listado::ordenar::caros-eurm2" data-xiti-shared-n2="true"> Caros eur/m&sup2; </a> </li> <li> <a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/?ordenado-por=area-desc" data-value="area-desc" class="" data-xiti-page="listado::ordenar::grandes" data-xiti-shared-n2="true"> Grandes </a> </li> <li> <a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/?ordenado-por=area-asc" data-value="area-asc" class="" data-xiti-page="listado::ordenar::pequeños" data-xiti-shared-n2="true"> Pequeños </a> </li> <li> <a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/?ordenado-por=planta-desc" data-value="planta-desc" rel='nofollow' class="" data-xiti-page="listado::ordenar::altos" data-xiti-shared-n2="true"> Pisos altos </a> </li> <li> <a href="/venta-viviendas/cartagena/cartagena/casco-antiguo/?ordenado-por=planta-asc" data-value="planta-asc" class="" rel='nofollow' data-xiti-page="listado::ordenar::bajos" data-xiti-shared-n2="true"> Pisos bajos </a> </li> </ul> </li> </ul> </div> </div> </div> <div class="items-container"> <article> <div class="item item_contains_branding item_featured item_highlight-phrase item_hightop" data-adid="81564623"> <div class="item-highlight-phrase">Las Mejores vistas de la Ciudad!</div> <div class="item-multimedia-container clearfix"> <div class="item-multimedia "> <div class="item-multimedia-features"> <span class="icon-3d-tour"></span> </div> <div class="item-multimedia-pictures"> <span class="icon-photos"></span> <span data-count></span><span data-total>32</span> </div> <div class="item-ribbon-container"> </div> <span class="item-push-up txt-caption">Destacado</span> <div class="item-gallery"> <div class="gallery-fallback icon-no-pics"> <img data-ondemand-img="https://img3.idealista.com/blur/WEB_LISTING_TOP/0/id.pro.es.image.master/47/02/e9/579313430.jpg" src="https://st1.idealista.com/static/common/img/icons/px.png" class="vertical"> </div> </div> </div> <div class="item-info-container"> <div class="logo-branding"> <a href='/pro/cartagena-homes-inmobiliaria/' data-xiti-click="listado::logo-agencia" title="Cartagena Homes-Inmobiliaria"> <div class="logo-border"></div> <img data-ondemand-img="https://st3.idealista.com/da/35/2c/cartagena-homes-inmobiliaria.gif" src="https://st1.idealista.com/static/common/img/icons/px.png" alt="Cartagena Homes-Inmobiliaria"> </a> </div> <a href="/inmueble/81564623/" class="item-link " title="Piso en calle Muralla del Mar, Casco Antiguo, Cartagena">Piso en calle Muralla del Mar, Casco Antiguo, Cartagena</a> <div class="row price-row clearfix"> <span class="item-price h2-simulated">399.000<span class="txt-big">€</span></span> </div> <span class="item-detail">4 <small>hab.</small></span> <span class="item-detail">231 <small>m²</small></span> <span class="item-detail">7ª <small>planta exterior con ascensor</small></span> <div class="item-description description"><p class="ellipsis">ZONA: MURALLA DEL MAR, la zona más deseada y exclusiva de la Ciudad. En el conocido Edificio Viking, disponemos de 231m² en 7º Planta con una de las mejores vistas a la dársena de Cartagena. Destacaremos su gran salón de 50m² volcado al puerto de Cartagena, 4 amplios dormitorios y una generosa c...</p></div> <div class="item-toolbar clearfix"> <div class="item-toolbar-contact"> <span class="icon-phone item-not-clickable-phone">968 915 296</span> <a class="icon-phone phone-btn item-clickable-phone" target="_blank" href="tel:968915296" data-xiti-markup='{ "click": {"xtPage":"listado::conversiones::contacto-por-telf","mustXtn2":true,"actionType":"PAGE"} }' data-xiti-page="telf_cliente_v"> <span>968 915 296</span> </a> <button class="icon-mail email-btn action-email fake-anchor"><span>Contactar</span></button> </div> <div class="item-toolbar-actions"> <button class="icon-fav favorite-btn action-fav fake-anchor" data-role="add" data-text-add="Guardar" data-text-remove="Quitar"> <span>Guardar</span> </button> <button class="icon-delete trash-btn action-discard fake-anchor" data-role="add" data-text-remove="Descartar" rel="nofollow"><span>Descartar</span></button> </div> </div> </div> </div> </div> </article> <article> <div class="item item_contains_branding item_featured item_highlight-phrase item_hightop" data-adid="81261953"> <div class="item-highlight-phrase">Pisazo en Calle del Carmen</div> <div class="item-multimedia-container clearfix"> <div class="item-multimedia "> <div class="item-multimedia-pictures"> <span class="icon-photos"></span> <span data-count></span><span data-total>32</span> </div> <div class="item-ribbon-container"> </div> <span class="item-push-up txt-caption">Destacado</span> <div class="item-gallery"> <div class="gallery-fallback icon-no-pics"> <img data-ondemand-img="https://img3.idealista.com/blur/WEB_LISTING_TOP/0/id.pro.es.image.master/ce/bb/81/573378877.jpg" src="https://st1.idealista.com/static/common/img/icons/px.png" class="vertical"> </div> </div> </div> <div class="item-info-container"> <div class="logo-branding"> <a href='/pro/cartagena-homes-inmobiliaria/' data-xiti-click="listado::logo-agencia" title="Cartagena Homes-Inmobiliaria"> <div class="logo-border"></div> <img data-ondemand-img="https://st3.idealista.com/da/35/2c/cartagena-homes-inmobiliaria.gif" src="https://st1.idealista.com/static/common/img/icons/px.png" alt="Cartagena Homes-Inmobiliaria"> </a> </div> <a href="/inmueble/81261953/" class="item-link " title="Piso en calle Carmen, Casco Antiguo, Cartagena">Piso en calle Carmen, Casco Antiguo, Cartagena</a> <div class="row price-row clearfix"> <span class="item-price h2-simulated">248.900<span class="txt-big">€</span></span> </div> <span class="item-detail">4 <small>hab.</small></span> <span class="item-detail">191 <small>m²</small></span> <span class="item-detail">5ª <small>planta exterior con ascensor</small></span> <div class="item-description description"><p class="ellipsis">Amplio piso de 175m², en, 5º Planta, orientación Este, con suelos de parquet, perfecto para que diseñes tu nueva casa con amplios dormitorios, salon de 40m² y en una de las calles más valoradas de la ciudad. el edificio donde se ubica este inmueble, es el conocido como "Edificio España", un edi...</p></div> <div class="item-toolbar clearfix"> <div class="item-toolbar-contact"> <span class="icon-phone item-not-clickable-phone">968 915 296</span> <a class="icon-phone phone-btn item-clickable-phone" target="_blank" href="tel:968915296" data-xiti-markup='{ "click": {"xtPage":"listado::conversiones::contacto-por-telf","mustXtn2":true,"actionType":"PAGE"} }' data-xiti-page="telf_cliente_v"> <span>968 915 296</span> </a> <button class="icon-mail email-btn action-email fake-anchor"><span>Contactar</span></button> </div> <div class="item-toolbar-actions"> <button class="icon-fav favorite-btn action-fav fake-anchor" data-role="add" data-text-add="Guardar" data-text-remove="Quitar"> <span>Guardar</span> </button> <button class="icon-delete trash-btn action-discard fake-anchor" data-role="add" data-text-remove="Descartar" rel="nofollow"><span>Descartar</span></button> </div> </div> </div> </div> </div> </article> <article> <div class="item item_contains_branding item_featured item_highlight-phrase item_hightop" data-adid="81469320"> <div class="item-highlight-phrase">Plaza de España! 200 metros para que te hagas la casa de tu vida</div> <div class="item-multimedia-container clearfix"> <div class="item-multimedia "> <div class="item-multimedia-pictures"> <span class="icon-photos"></span> <span data-count></span><span data-total>10</span> </div> <div class="item-ribbon-container"> </div> <span class="item-push-up txt-caption">Destacado</span> <div class="item-gallery"> <div class="gallery-fallback icon-no-pics"> <img data-ondemand-img="https://img3.idealista.com/blur/WEB_LISTING_TOP/0/id.pro.es.image.master/6b/3c/82/577523206.jpg" src="https://st1.idealista.com/static/common/img/icons/px.png" class="vertical"> </div> </div> </div> <div class="item-info-container"> <div class="logo-branding"> <a href='/pro/cartagena-homes-inmobiliaria/' data-xiti-click="listado::logo-agencia" title="Cartagena Homes-Inmobiliaria"> <div class="logo-border"></div> <img data-ondemand-img="https://st3.idealista.com/da/35/2c/cartagena-homes-inmobiliaria.gif" src="https://st1.idealista.com/static/common/img/icons/px.png" alt="Cartagena Homes-Inmobiliaria"> </a> </div> <a href="/inmueble/81469320/" class="item-link " title="Piso en plaza de España, Casco Antiguo, Cartagena">Piso en plaza de España, Casco Antiguo, Cartagena</a> <div class="row price-row clearfix"> <span class="item-price h2-simulated">199.000<span class="txt-big">€</span></span> </div> <span class="item-detail">4 <small>hab.</small></span> <span class="item-detail">199 <small>m²</small></span> <span class="item-detail">3ª <small>planta exterior con ascensor</small></span> <div class="item-description description"><p class="ellipsis">Excelente oportunidad! si buscas una casa con metros, exterior, bien ubicada y con mil posibilidades de reforma, valora esta publicación un minuto. hablamos de un piso de casi 200m² ubicado en plaza de España, justo a la entrada del casco antiguo y completamente exterior, la vivienda se encuentra...</p></div> <div class="item-toolbar clearfix"> <div class="item-toolbar-contact"> <span class="icon-phone item-not-clickable-phone">968 915 296</span> <a class="icon-phone phone-btn item-clickable-phone" target="_blank" href="tel:968915296" data-xiti-markup='{ "click": {"xtPage":"listado::conversiones::contacto-por-telf","mustXtn2":true,"actionType":"PAGE"} }' data-xiti-page="telf_cliente_v"> <span>968 915 296</span> </a> <button class="icon-mail email-btn action-email fake-anchor"><span>Contactar</span></button> </div> <div class="item-toolbar-actions"> <button class="icon-fav favorite-btn action-fav fake-anchor" data-role="add" data-text-add="Guardar" data-text-remove="Quitar"> <span>Guardar</span> </button> <button class="icon-delete trash-btn action-discard fake-anchor" data-role="add" data-text-remove="Descartar" rel="nofollow"><span>Descartar</span></button> </div> </div> </div> </div> </div> </article> <article> <div class="item item_contains_branding item_featured item_highlight-phrase" data-adid="37758001"> <div class="item-highlight-phrase">Atico a estrenar en pleno centro!</div> <div class="item-multimedia-container clearfix"> <div class="item-multimedia "> <div class="item-multimedia-features"> <span class="icon-3d-tour"></span> <span class="icon-virtual-tour"></span> <span class="icon-plans"></span> </div> <div class="item-multimedia-pictures"> <span class="icon-photos"></span> <span data-count></span><span data-total>36</span> </div> <div class="item-ribbon-container"> </div> <span class="item-push-up txt-caption">Destacado</span> <div class="item-gallery"> <div class="gallery-fallback icon-no-pics"> <img data-ondemand-img="https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/97/6c/57/281218234.jpg" src="https://st1.idealista.com/static/common/img/icons/px.png" class="vertical"> </div> </div> </div> <div class="item-info-container"> <div class="logo-branding"> <a href='/pro/cartagena-homes-inmobiliaria/' data-xiti-click="listado::logo-agencia" title="Cartagena Homes-Inmobiliaria"> <div class="logo-border"></div> <img data-ondemand-img="https://st3.idealista.com/da/35/2c/cartagena-homes-inmobiliaria.gif" src="https://st1.idealista.com/static/common/img/icons/px.png" alt="Cartagena Homes-Inmobiliaria"> </a> </div> <a href="/inmueble/37758001/" class="item-link " title="Dúplex en calle carlos iii, 33, Casco Antiguo, Cartagena">Dúplex en calle carlos iii, 33, Casco Antiguo, Cartagena</a> <div class="row price-row clearfix"> <span class="item-price h2-simulated">240.000<span class="txt-big">€</span></span> <span class="item-parking">Garaje incluido</span> </div> <span class="item-detail">3 <small>hab.</small></span> <span class="item-detail">128 <small>m²</small></span> <span class="item-detail">5ª <small>planta exterior con ascensor</small></span> <div class="item-description description"><p class="ellipsis">En la actualidad, el producto más demandado por las familias jóvenes con hijos de Cartagena es el piso de 3 dormitorios y 2 baños con plaza de garaje en el mismo edificio, con poca antiguedad y si tiene terraza para que los más peques puedan jugar al aire libre, mucho mejor. Pues fíjate bien en e...</p></div> <div class="item-toolbar clearfix"> <div class="item-toolbar-contact"> <span class="icon-phone item-not-clickable-phone">968 915 296</span> <a class="icon-phone phone-btn item-clickable-phone" target="_blank" href="tel:968915296" data-xiti-markup='{ "click": {"xtPage":"listado::conversiones::contacto-por-telf","mustXtn2":true,"actionType":"PAGE"} }' data-xiti-page="telf_cliente_v"> <span>968 915 296</span> </a> <button class="icon-mail email-btn action-email fake-anchor"><span>Contactar</span></button> </div> <div class="item-toolbar-actions"> <button class="icon-fav favorite-btn action-fav fake-anchor" data-role="add" data-text-add="Guardar" data-text-remove="Quitar"> <span>Guardar</span> </button> <button class="icon-delete trash-btn action-discard fake-anchor" data-role="add" data-text-remove="Descartar" rel="nofollow"><span>Descartar</span></button> </div> </div> </div> </div> </div> </article> <article class="adv noHover"> <div id="banners_16022"> <p class="adv_txt">Publicidad</p> <div id="sas_16022"></div> <script type="text/javascript">
                            sas.cmd.push(function() {
                                sas.render('16022');
                            });
                        </script> </div> </article> <article> <div class="item item_contains_branding" data-adid="36198826"> <div class="item-multimedia-container clearfix"> <div class="item-multimedia "> <div class="item-multimedia-features"> <span class="icon-3d-tour"></span> </div> <div class="item-multimedia-pictures"> <span class="icon-photos"></span> <span data-count></span><span data-total>23</span> </div> <div class="item-ribbon-container"> </div> <span class="item-push-up txt-caption">Destacado</span> <div class="item-gallery"> <div class="gallery-fallback icon-no-pics"> <img data-ondemand-img="https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/a5/65/cb/273589866.jpg" src="https://st1.idealista.com/static/common/img/icons/px.png" class="vertical"> </div> </div> </div> <div class="item-info-container"> <div class="logo-branding"> <a href='/pro/cartagena-homes-inmobiliaria/' data-xiti-click="listado::logo-agencia" title="Cartagena Homes-Inmobiliaria"> <div class="logo-border"></div> <img data-ondemand-img="https://st3.idealista.com/da/35/2c/cartagena-homes-inmobiliaria.gif" src="https://st1.idealista.com/static/common/img/icons/px.png" alt="Cartagena Homes-Inmobiliaria"> </a> </div> <a href="/inmueble/36198826/" class="item-link " title="Piso en calle carmen, 57, Casco Antiguo, Cartagena">Piso en calle carmen, 57, Casco Antiguo, Cartagena</a> <div class="row price-row clearfix"> <span class="item-price h2-simulated">285.000<span class="txt-big">€</span></span> <span class="item-parking">Garaje incluido</span> </div> <span class="item-detail">3 <small>hab.</small></span> <span class="item-detail">103 <small>m²</small></span> <span class="item-detail">4ª <small>planta exterior con ascensor</small></span> <div class="item-description description"><p class="ellipsis">¿Quieres vivir en el centro en un edificio nuevo pero a la vez compartiendo un trocito de historia de Cartagena? Magnífica oportunidad de vivir en un edificio nuevo con grandes acabados, plaza de garaje y trastero en el centro. Se compone de 3 dormitorios con a/e, 2 baños completos, salón-comedo...</p></div> <div class="item-toolbar clearfix"> <div class="item-toolbar-contact"> <span class="icon-phone item-not-clickable-phone">968 915 296</span> <a class="icon-phone phone-btn item-clickable-phone" target="_blank" href="tel:968915296" data-xiti-markup='{ "click": {"xtPage":"listado::conversiones::contacto-por-telf","mustXtn2":true,"actionType":"PAGE"} }' data-xiti-page="telf_cliente_v"> <span>968 915 296</span> </a> <button class="icon-mail email-btn action-email fake-anchor"><span>Contactar</span></button> </div> <div class="item-toolbar-actions"> <button class="icon-fav favorite-btn action-fav fake-anchor" data-role="add" data-text-add="Guardar" data-text-remove="Quitar"> <span>Guardar</span> </button> <button class="icon-delete trash-btn action-discard fake-anchor" data-role="add" data-text-remove="Descartar" rel="nofollow"><span>Descartar</span></button> </div> </div> </div> </div> </div> </article> <article> <div class="item item_contains_branding item_featured item_highlight-phrase" data-adid="40534909"> <div class="item-highlight-phrase">ATICO EN PLENO CENTRO DE LA CIUDAD, CALLE MAYOR !!!</div> <div class="item-multimedia-container clearfix"> <div class="item-multimedia "> <div class="item-multimedia-features"> <span class="icon-virtual-tour"></span> <span class="icon-plans"></span> </div> <div class="item-multimedia-pictures"> <span class="icon-photos"></span> <span data-count></span><span data-total>31</span> </div> <div class="item-ribbon-container"> </div> <span class="item-push-up txt-caption">Destacado</span> <div class="item-gallery"> <div class="gallery-fallback icon-no-pics"> <img data-ondemand-img="https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/fb/58/18/571673334.jpg" src="https://st1.idealista.com/static/common/img/icons/px.png" class="vertical"> </div> </div> </div> <div class="item-info-container"> <div class="logo-branding"> <a href='/pro/inmobiliaria-fincas/' data-xiti-click="listado::logo-agencia" title="inmobiliaria fincas"> <div class="logo-border"></div> <img data-ondemand-img="https://st3.idealista.com/7f/c7/82/inmobiliaria-fincas.gif" src="https://st1.idealista.com/static/common/img/icons/px.png" alt="inmobiliaria fincas"> </a> </div> <a href="/inmueble/40534909/" class="item-link " title="Ático en Casco Antiguo, Cartagena">Ático en Casco Antiguo, Cartagena</a> <div class="row price-row clearfix"> <span class="item-price h2-simulated">229.000<span class="txt-big">€</span></span> </div> <span class="item-detail">3 <small>hab.</small></span> <span class="item-detail">111 <small>m²</small></span> <span class="item-detail">7ª <small>planta exterior con ascensor</small></span> <div class="item-description description"><p class="ellipsis">¿ Te apetece vivir en un atico en plena calle Mayor de Cartagena? Quieres despertarte mirando al monte de Galeras? O quizas quieras leer un libro en tu salon con vistas al monte de fajardo. Si es asi, aqui tienes tu oportunidad, espectacular atico con terraza de 30 m2. No dejes de ir a visitarl...</p></div> <div class="item-toolbar clearfix"> <div class="item-toolbar-contact"> <span class="icon-phone item-not-clickable-phone">968 914 039</span> <a class="icon-phone phone-btn item-clickable-phone" target="_blank" href="tel:968914039" data-xiti-markup='{ "click": {"xtPage":"listado::conversiones::contacto-por-telf","mustXtn2":true,"actionType":"PAGE"} }' data-xiti-page="telf_cliente_v"> <span>968 914 039</span> </a> <button class="icon-mail email-btn action-email fake-anchor"><span>Contactar</span></button> </div> <div class="item-toolbar-actions"> <button class="icon-fav favorite-btn action-fav fake-anchor" data-role="add" data-text-add="Guardar" data-text-remove="Quitar"> <span>Guardar</span> </button> <button class="icon-delete trash-btn action-discard fake-anchor" data-role="add" data-text-remove="Descartar" rel="nofollow"><span>Descartar</span></button> </div> </div> </div> </div> </div> </article> <article> <div class="item item_contains_branding item_featured item_highlight-phrase" data-adid="34959237"> <div class="item-highlight-phrase">Uno de los mejores pisos de Cartagena.</div> <div class="item-multimedia-container clearfix"> <div class="item-multimedia "> <div class="item-multimedia-features"> <span class="icon-virtual-tour"></span> </div> <div class="item-multimedia-pictures"> <span class="icon-photos"></span> <span data-count></span><span data-total>40</span> </div> <div class="item-ribbon-container"> </div> <span class="item-push-up txt-caption">Destacado</span> <div class="item-gallery"> <div class="gallery-fallback icon-no-pics"> <img data-ondemand-img="https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/89/f5/5b/193492839.jpg" src="https://st1.idealista.com/static/common/img/icons/px.png" class="vertical"> </div> </div> </div> <div class="item-info-container"> <div class="logo-branding"> <a href='/pro/cartagena-homes-inmobiliaria/' data-xiti-click="listado::logo-agencia" title="Cartagena Homes-Inmobiliaria"> <div class="logo-border"></div> <img data-ondemand-img="https://st3.idealista.com/da/35/2c/cartagena-homes-inmobiliaria.gif" src="https://st1.idealista.com/static/common/img/icons/px.png" alt="Cartagena Homes-Inmobiliaria"> </a> </div> <a href="/inmueble/34959237/" class="item-link " title="Piso en calle jara, Casco Antiguo, Cartagena">Piso en calle jara, Casco Antiguo, Cartagena</a> <div class="row price-row clearfix"> <span class="item-price h2-simulated">300.000<span class="txt-big">€</span></span> </div> <span class="item-detail">5 <small>hab.</small></span> <span class="item-detail">218 <small>m²</small></span> <span class="item-detail">6ª <small>planta exterior con ascensor</small></span> <div class="item-description description"><p class="ellipsis">Muy pocas veces una casa reúne tantas cualidades como esta, UBICACIÓN (pleno centro), TAMAÑO (218m²), ALTURA (6ª planta) Y ORIENTACIÓN (sur), estas son cualidades que una vez comprada una casa nunca podrás cambiar, el ESTADO si no te gusta reformas, PLAZA DE GARAJE si no tiene puedes alquilar o c...</p></div> <div class="item-toolbar clearfix"> <div class="item-toolbar-contact"> <span class="icon-phone item-not-clickable-phone">968 915 296</span> <a class="icon-phone phone-btn item-clickable-phone" target="_blank" href="tel:968915296" data-xiti-markup='{ "click": {"xtPage":"listado::conversiones::contacto-por-telf","mustXtn2":true,"actionType":"PAGE"} }' data-xiti-page="telf_cliente_v"> <span>968 915 296</span> </a> <button class="icon-mail email-btn action-email fake-anchor"><span>Contactar</span></button> </div> <div class="item-toolbar-actions"> <button class="icon-fav favorite-btn action-fav fake-anchor" data-role="add" data-text-add="Guardar" data-text-remove="Quitar"> <span>Guardar</span> </button> <button class="icon-delete trash-btn action-discard fake-anchor" data-role="add" data-text-remove="Descartar" rel="nofollow"><span>Descartar</span></button> </div> </div> </div> </div> </div> </article> <article> <div class="item item_contains_branding" data-adid="33083937"> <div class="item-multimedia-container clearfix"> <div class="item-multimedia "> <div class="item-multimedia-features"> <span class="icon-virtual-tour"></span> </div> <div class="item-multimedia-pictures"> <span class="icon-photos"></span> <span data-count></span><span data-total>27</span> </div> <div class="item-ribbon-container"> </div> <span class="item-push-up txt-caption">Destacado</span> <div class="item-gallery"> <div class="gallery-fallback icon-no-pics"> <img data-ondemand-img="https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/be/89/f3/574863647.jpg" src="https://st1.idealista.com/static/common/img/icons/px.png" class="vertical"> </div> </div> </div> <div class="item-info-container"> <div class="logo-branding"> <a href='/pro/cartagena-homes-inmobiliaria/' data-xiti-click="listado::logo-agencia" title="Cartagena Homes-Inmobiliaria"> <div class="logo-border"></div> <img data-ondemand-img="https://st3.idealista.com/da/35/2c/cartagena-homes-inmobiliaria.gif" src="https://st1.idealista.com/static/common/img/icons/px.png" alt="Cartagena Homes-Inmobiliaria"> </a> </div> <a href="/inmueble/33083937/" class="item-link " title="Piso en calle tolosa latour, Casco Antiguo, Cartagena">Piso en calle tolosa latour, Casco Antiguo, Cartagena</a> <div class="row price-row clearfix"> <span class="item-price h2-simulated">215.000<span class="txt-big">€</span></span> </div> <span class="item-detail">5 <small>hab.</small></span> <span class="item-detail">163 <small>m²</small></span> <span class="item-detail">12ª <small>planta exterior con ascensor</small></span> <div class="item-description description"><p class="ellipsis">A la puertas del Casco Histórico, se ubica uno de los edificios mas conocidos de Cartagena, amplios pisos en distribuidos en 15 plantas, el edificio dispone en su semisotano de parking con vigilancia las 24h y un conserje en recepción del edificio que controla el acceso al edificio y ayuda a los...</p></div> <div class="item-toolbar clearfix"> <div class="item-toolbar-contact"> <span class="icon-phone item-not-clickable-phone">968 915 296</span> <a class="icon-phone phone-btn item-clickable-phone" target="_blank" href="tel:968915296" data-xiti-markup='{ "click": {"xtPage":"listado::conversiones::contacto-por-telf","mustXtn2":true,"actionType":"PAGE"} }' data-xiti-page="telf_cliente_v"> <span>968 915 296</span> </a> <button class="icon-mail email-btn action-email fake-anchor"><span>Contactar</span></button> </div> <div class="item-toolbar-actions"> <button class="icon-fav favorite-btn action-fav fake-anchor" data-role="add" data-text-add="Guardar" data-text-remove="Quitar"> <span>Guardar</span> </button> <button class="icon-delete trash-btn action-discard fake-anchor" data-role="add" data-text-remove="Descartar" rel="nofollow"><span>Descartar</span></button> </div> </div> </div> </div> </div> </article> <article> <div class="item item_contains_branding item_featured item_highlight-phrase" data-adid="32180475"> <div class="item-highlight-phrase">Piso en Cartagena Calle Gisbert.</div> <div class="item-multimedia-container clearfix"> <div class="item-multimedia "> <div class="item-multimedia-features"> <span class="icon-virtual-tour"></span> </div> <div class="item-multimedia-pictures"> <span class="icon-photos"></span> <span data-count></span><span data-total>16</span> </div> <div class="item-ribbon-container"> </div> <span class="item-push-up txt-caption">Destacado</span> <div class="item-gallery"> <div class="gallery-fallback icon-no-pics"> <img data-ondemand-img="https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/e6/2b/9a/573528360.jpg" src="https://st1.idealista.com/static/common/img/icons/px.png" class="vertical"> </div> </div> </div> <div class="item-info-container"> <div class="logo-branding"> <a href='/pro/gesprocasa/' data-xiti-click="listado::logo-agencia" title="Gesprocasa"> <div class="logo-border"></div> <img data-ondemand-img="https://st3.idealista.com/3d/6c/38/gesprocasa.gif" src="https://st1.idealista.com/static/common/img/icons/px.png" alt="Gesprocasa"> </a> </div> <a href="/inmueble/32180475/" class="item-link " title="Piso en calle gisbert, 7, Casco Antiguo, Cartagena">Piso en calle gisbert, 7, Casco Antiguo, Cartagena</a> <div class="row price-row clearfix"> <span class="item-price h2-simulated">124.500<span class="txt-big">€</span></span> <span class="item-parking">Garaje incluido</span> </div> <span class="item-detail">2 <small>hab.</small></span> <span class="item-detail">79 <small>m²</small></span> <span class="item-detail">3ª <small>planta exterior con ascensor</small></span> <div class="item-description description"><p class="ellipsis">Quieres vivir en El Centro de Cartagena? Buscas disfrutar de los encantos que ofrece esta preciosa ciudad? De su semana Santa? De sus carnavales? De su puerto? . y todo ello sin prácticamente moverte de casa? Pues si es así aquí tienes tu nuevo hogar.. . Un piso totalmente amueblado listo para en...</p></div> <div class="item-toolbar clearfix"> <div class="item-toolbar-contact"> <span class="icon-phone item-not-clickable-phone">868 861 073</span> <a class="icon-phone phone-btn item-clickable-phone" target="_blank" href="tel:868861073" data-xiti-markup='{ "click": {"xtPage":"listado::conversiones::contacto-por-telf","mustXtn2":true,"actionType":"PAGE"} }' data-xiti-page="telf_cliente_v"> <span>868 861 073</span> </a> <button class="icon-mail email-btn action-email fake-anchor"><span>Contactar</span></button> </div> <div class="item-toolbar-actions"> <button class="icon-fav favorite-btn action-fav fake-anchor" data-role="add" data-text-add="Guardar" data-text-remove="Quitar"> <span>Guardar</span> </button> <button class="icon-delete trash-btn action-discard fake-anchor" data-role="add" data-text-remove="Descartar" rel="nofollow"><span>Descartar</span></button> </div> </div> </div> </div> </div> </article> <div id="experts"> <h6>Inmobiliarias en Casco Antiguo</h6> <div class="msa"> <div class="highcards"></div> </div> <a class="more" href="/pro/venta-viviendas/cartagena/cartagena/casco-antiguo/agencias-inmobiliarias" title="Inmobiliarias en Casco Antiguo"> Inmobiliarias en Casco Antiguo </a> </div> <article> <div class="item item_contains_branding" data-adid="40465575"> <div class="item-multimedia-container clearfix"> <div class="item-multimedia "> <div class="item-multimedia-features"> <span class="icon-plans"></span> </div> <div class="item-multimedia-pictures"> <span class="icon-photos"></span> <span data-count></span><span data-total>31</span> </div> <div class="item-ribbon-container"> </div> <span class="item-push-up txt-caption">Destacado</span> <div class="item-gallery"> <div class="gallery-fallback icon-no-pics"> <img data-ondemand-img="https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/49/c2/a2/281144396.jpg" src="https://st1.idealista.com/static/common/img/icons/px.png" class="vertical"> </div> </div> </div> <div class="item-info-container"> <div class="logo-branding"> <a href='/pro/globalmoller/' data-xiti-click="listado::logo-agencia" title="GLOBAL MÖLLER"> <div class="logo-border"></div> <img data-ondemand-img="https://st3.idealista.com/e7/73/64/globalmoller.gif" src="https://st1.idealista.com/static/common/img/icons/px.png" alt="GLOBAL MÖLLER"> </a> </div> <a href="/inmueble/40465575/" class="item-link " title="Piso en Juan Fernández, 4, Casco Antiguo, Cartagena">Piso en Juan Fernández, 4, Casco Antiguo, Cartagena</a> <div class="row price-row clearfix"> <span class="item-price h2-simulated">110.000<span class="txt-big">€</span></span> <span class="pricedown"> <span class="pricedown_price"> 115.000 € </span> <span class="pricedown_icon icon-pricedown">4%</span> </span> </div> <span class="item-detail">4 <small>hab.</small></span> <span class="item-detail">100 <small>m²</small></span> <span class="item-detail">7ª <small>planta exterior con ascensor</small></span> <div class="item-description description"><p class="ellipsis">JUAN FERNÁNDEZ Nº4, CENTRO DE CARTAGENA. GLOBAL MÖLLER vende Vivienda Muy Luminosa, ubicada en 7ª Planta de un total de 8 alturas. Edificación con 2 Ascensores. Ubicación determinante, frente a Mercado Santa Florentina. Muy próximo a Paseo Alfonso XIII, y Plaza Juan XXIII. Centro Ciudad. Orienta...</p></div> <div class="item-toolbar clearfix"> <div class="item-toolbar-contact"> <span class="icon-phone item-not-clickable-phone">968 916 871</span> <a class="icon-phone phone-btn item-clickable-phone" target="_blank" href="tel:968916871" data-xiti-markup='{ "click": {"xtPage":"listado::conversiones::contacto-por-telf","mustXtn2":true,"actionType":"PAGE"} }' data-xiti-page="telf_cliente_v"> <span>968 916 871</span> </a> <button class="icon-mail email-btn action-email fake-anchor"><span>Contactar</span></button> </div> <div class="item-toolbar-actions"> <button class="icon-fav favorite-btn action-fav fake-anchor" data-role="add" data-text-add="Guardar" data-text-remove="Quitar"> <span>Guardar</span> </button> <button class="icon-delete trash-btn action-discard fake-anchor" data-role="add" data-text-remove="Descartar" rel="nofollow"><span>Descartar</span></button> </div> </div> </div> </div> </div> </article> <article> <div class="item item_contains_branding" data-adid="40375131"> <div class="item-multimedia-container clearfix"> <div class="item-multimedia "> <div class="item-multimedia-features"> <span class="icon-plans"></span> </div> <div class="item-multimedia-pictures"> <span class="icon-photos"></span> <span data-count></span><span data-total>31</span> </div> <div class="item-ribbon-container"> </div> <span class="item-push-up txt-caption">Destacado</span> <div class="item-gallery"> <div class="gallery-fallback icon-no-pics"> <img data-ondemand-img="https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/4d/e6/0e/279089020.jpg" src="https://st1.idealista.com/static/common/img/icons/px.png" class="vertical"> </div> </div> </div> <div class="item-info-container"> <div class="logo-branding"> <a href='/pro/globalmoller/' data-xiti-click="listado::logo-agencia" title="GLOBAL MÖLLER"> <div class="logo-border"></div> <img data-ondemand-img="https://st3.idealista.com/e7/73/64/globalmoller.gif" src="https://st1.idealista.com/static/common/img/icons/px.png" alt="GLOBAL MÖLLER"> </a> </div> <a href="/inmueble/40375131/" class="item-link " title="Piso en Juan Fernández, 4, Casco Antiguo, Cartagena">Piso en Juan Fernández, 4, Casco Antiguo, Cartagena</a> <div class="row price-row clearfix"> <span class="item-price h2-simulated">110.000<span class="txt-big">€</span></span> <span class="pricedown"> <span class="pricedown_price"> 115.000 € </span> <span class="pricedown_icon icon-pricedown">4%</span> </span> </div> <span class="item-detail">4 <small>hab.</small></span> <span class="item-detail">100 <small>m²</small></span> <span class="item-detail">7ª <small>planta exterior con ascensor</small></span> <div class="item-description description"><p class="ellipsis">JUAN FERNÁNDEZ Nº4, CENTRO DE CARTAGENA. GLOBAL MÖLLER vende Vivienda Muy Luminosa, ubicada en 7ª Planta de un total de 8 alturas. Edificación con 2 Ascensores. Ubicación determinante, frente a Mercado Santa Florentina. Muy próximo a Paseo Alfonso XIII, y Plaza Juan XXIII. Centro Ciudad. Orienta...</p></div> <div class="item-toolbar clearfix"> <div class="item-toolbar-contact"> <span class="icon-phone item-not-clickable-phone">968 916 871</span> <a class="icon-phone phone-btn item-clickable-phone" target="_blank" href="tel:968916871" data-xiti-markup='{ "click": {"xtPage":"listado::conversiones::contacto-por-telf","mustXtn2":true,"actionType":"PAGE"} }' data-xiti-page="telf_cliente_v"> <span>968 916 871</span> </a> <button class="icon-mail email-btn action-email fake-anchor"><span>Contactar</span></button> </div> <div class="item-toolbar-actions"> <button class="icon-fav favorite-btn action-fav fake-anchor" data-role="add" data-text-add="Guardar" data-text-remove="Quitar"> <span>Guardar</span> </button> <button class="icon-delete trash-btn action-discard fake-anchor" data-role="add" data-text-remove="Descartar" rel="nofollow"><span>Descartar</span></button> </div> </div> </div> </div> </div> </article> <article> <div class="item item_contains_branding" data-adid="39929137"> <div class="item-multimedia-container clearfix"> <div class="item-multimedia "> <div class="item-multimedia-features"> <span class="icon-plans"></span> </div> <div class="item-multimedia-pictures"> <span class="icon-photos"></span> <span data-count></span><span data-total>39</span> </div> <div class="item-ribbon-container"> </div> <span class="item-push-up txt-caption">Destacado</span> <div class="item-gallery"> <div class="gallery-fallback icon-no-pics"> <img data-ondemand-img="https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/92/41/b8/283594262.jpg" src="https://st1.idealista.com/static/common/img/icons/px.png" class="vertical"> </div> </div> </div> <div class="item-info-container"> <div class="logo-branding"> <a href='/pro/p29003309/' data-xiti-click="listado::logo-agencia" title="Inversa inmobiliaria"> <div class="logo-border"></div> <img data-ondemand-img="https://st3.idealista.com/7a/da/d9/p29003309.gif" src="https://st1.idealista.com/static/common/img/icons/px.png" alt="Inversa inmobiliaria"> </a> </div> <a href="/inmueble/39929137/" class="item-link " title="Ático en calle jara, Casco Antiguo, Cartagena">Ático en calle jara, Casco Antiguo, Cartagena</a> <div class="row price-row clearfix"> <span class="item-price h2-simulated">297.000<span class="txt-big">€</span></span> </div> <span class="item-detail">3 <small>hab.</small></span> <span class="item-detail">91 <small>m²</small></span> <span class="item-detail">4ª <small>planta exterior con ascensor</small></span> <div class="item-description description"><p class="ellipsis">CARTAGENA-CASCO HISTÓRICO. Sofisticado ático en uno de los edificios más bonitos de la calle Jara. Una posesión que satisface las más altas exigencias y con vistas únicas desde sus 2 terrazas de 30 m2 cada una Imagínate desayunando en la terraza Norte viendo el Parque Arqueológico del Molinete,...</p></div> <div class="item-toolbar clearfix"> <div class="item-toolbar-contact"> <span class="icon-phone item-not-clickable-phone">868 860 183</span> <a class="icon-phone phone-btn item-clickable-phone" target="_blank" href="tel:868860183" data-xiti-markup='{ "click": {"xtPage":"listado::conversiones::contacto-por-telf","mustXtn2":true,"actionType":"PAGE"} }' data-xiti-page="telf_cliente_v"> <span>868 860 183</span> </a> <button class="icon-mail email-btn action-email fake-anchor"><span>Contactar</span></button> </div> <div class="item-toolbar-actions"> <button class="icon-fav favorite-btn action-fav fake-anchor" data-role="add" data-text-add="Guardar" data-text-remove="Quitar"> <span>Guardar</span> </button> <button class="icon-delete trash-btn action-discard fake-anchor" data-role="add" data-text-remove="Descartar" rel="nofollow"><span>Descartar</span></button> </div> </div> </div> </div> </div> </article> <article> <div class="item item_contains_branding" data-adid="39535554"> <div class="item-multimedia-container clearfix"> <div class="item-multimedia "> <div class="item-multimedia-features"> <span class="icon-plans"></span> </div> <div class="item-multimedia-pictures"> <span class="icon-photos"></span> <span data-count></span><span data-total>23</span> </div> <div class="item-ribbon-container"> </div> <span class="item-push-up txt-caption">Destacado</span> <div class="item-gallery"> <div class="gallery-fallback icon-no-pics"> <img data-ondemand-img="https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/62/0b/44/271877374.jpg" src="https://st1.idealista.com/static/common/img/icons/px.png" class="vertical"> </div> </div> </div> <div class="item-info-container"> <div class="logo-branding"> <a href='/pro/ayala-y-asociados/' data-xiti-click="listado::logo-agencia" title="Ayala y asociados"> <div class="logo-border"></div> <img data-ondemand-img="https://st3.idealista.com/65/fb/2d/ayala-y-asociados.gif" src="https://st1.idealista.com/static/common/img/icons/px.png" alt="Ayala y asociados"> </a> </div> <a href="/inmueble/39535554/" class="item-link " title="Piso en plaza San Agustin, 8, Casco Antiguo, Cartagena">Piso en plaza San Agustin, 8, Casco Antiguo, Cartagena</a> <div class="row price-row clearfix"> <span class="item-price h2-simulated">255.000<span class="txt-big">€</span></span> <span class="item-parking">Garaje incluido</span> </div> <span class="item-detail">4 <small>hab.</small></span> <span class="item-detail">206 <small>m²</small></span> <span class="item-detail">1ª <small>planta exterior con ascensor</small></span> <div class="item-description description"><p class="ellipsis">“En esta vivienda disponemos de un presupuesto de reforma detallado e imágenes y vídeo infográfico de cómo podría quedar la vivienda una vez terminada. ” También dispone de un vídeo para que la puedan visitar virtualmente. Encontrarán el enlace bajo la descripción. Se vende piso en Plaza San Ag...</p></div> <div class="item-toolbar clearfix"> <div class="item-toolbar-contact"> <span class="icon-phone item-not-clickable-phone">968 913 766</span> <a class="icon-phone phone-btn item-clickable-phone" target="_blank" href="tel:968913766" data-xiti-markup='{ "click": {"xtPage":"listado::conversiones::contacto-por-telf","mustXtn2":true,"actionType":"PAGE"} }' data-xiti-page="telf_cliente_v"> <span>968 913 766</span> </a> <button class="icon-mail email-btn action-email fake-anchor"><span>Contactar</span></button> </div> <div class="item-toolbar-actions"> <button class="icon-fav favorite-btn action-fav fake-anchor" data-role="add" data-text-add="Guardar" data-text-remove="Quitar"> <span>Guardar</span> </button> <button class="icon-delete trash-btn action-discard fake-anchor" data-role="add" data-text-remove="Descartar" rel="nofollow"><span>Descartar</span></button> </div> </div> </div> </div> </div> </article> <article> <div class="item item_contains_branding" data-adid="81531516"> <div class="item-multimedia-container clearfix"> <div class="item-multimedia "> <div class="item-multimedia-features"> <span class="icon-plans"></span> </div> <div class="item-multimedia-pictures"> <span class="icon-photos"></span> <span data-count></span><span data-total>12</span> </div> <div class="item-ribbon-container"> </div> <span class="item-push-up txt-caption">Destacado</span> <div class="item-gallery"> <div class="gallery-fallback icon-no-pics"> <img data-ondemand-img="https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/d1/81/fe/578645034.jpg" src="https://st1.idealista.com/static/common/img/icons/px.png" class="vertical"> </div> </div> </div> <div class="item-info-container"> <div class="logo-branding"> <a href='/pro/ipropietarios/' data-xiti-click="listado::logo-agencia" title="Propietarios - Asesoría Inmobiliaria"> <div class="logo-border"></div> <img data-ondemand-img="https://st3.idealista.com/88/6b/1f/ipropietarios.gif" src="https://st1.idealista.com/static/common/img/icons/px.png" alt="Propietarios - Asesoría Inmobiliaria"> </a> </div> <a href="/inmueble/81531516/" class="item-link " title="Piso en calle Santa Florentina, 4, Casco Antiguo, Cartagena">Piso en calle Santa Florentina, 4, Casco Antiguo, Cartagena</a> <div class="row price-row clearfix"> <span class="item-price h2-simulated">250.000<span class="txt-big">€</span></span> </div> <span class="item-detail">3 <small>hab.</small></span> <span class="item-detail">85 <small>m²</small></span> <span class="item-detail">1ª <small>planta exterior con ascensor</small></span> <div class="item-description description"><p class="ellipsis">PROMOCION EN EXCLUSIVA EN LA CALLE SANTA FLORENTINA. PUNTO UNICO DE VENTA. DIRECTO DE PROMOTOR. Viviendas tipo piso de 3 dorm. en pleno centro de Cartagena, con calidades de tipo alto, con fachada exterior con diseño innovador, y fachada a Sta. Florentina con limpieza y consolidación del ladrillo...</p></div> <div class="item-toolbar clearfix"> <div class="item-toolbar-contact"> <span class="icon-phone item-not-clickable-phone">868 863 364</span> <a class="icon-phone phone-btn item-clickable-phone" target="_blank" href="tel:868863364" data-xiti-markup='{ "click": {"xtPage":"listado::conversiones::contacto-por-telf","mustXtn2":true,"actionType":"PAGE"} }' data-xiti-page="telf_cliente_v"> <span>868 863 364</span> </a> <button class="icon-mail email-btn action-email fake-anchor"><span>Contactar</span></button> </div> <div class="item-toolbar-actions"> <button class="icon-fav favorite-btn action-fav fake-anchor" data-role="add" data-text-add="Guardar" data-text-remove="Quitar"> <span>Guardar</span> </button> <button class="icon-delete trash-btn action-discard fake-anchor" data-role="add" data-text-remove="Descartar" rel="nofollow"><span>Descartar</span></button> </div> </div> </div> </div> </div> </article> <article> <div class="item item_contains_branding" data-adid="81531208"> <div class="item-multimedia-container clearfix"> <div class="item-multimedia "> <div class="item-multimedia-features"> <span class="icon-plans"></span> </div> <div class="item-multimedia-pictures"> <span class="icon-photos"></span> <span data-count></span><span data-total>8</span> </div> <div class="item-ribbon-container"> </div> <span class="item-push-up txt-caption">Destacado</span> <div class="item-gallery"> <div class="gallery-fallback icon-no-pics"> <img data-ondemand-img="https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/c2/5f/2d/578639643.jpg" src="https://st1.idealista.com/static/common/img/icons/px.png" class="vertical"> </div> </div> </div> <div class="item-info-container"> <div class="logo-branding"> <a href='/pro/ipropietarios/' data-xiti-click="listado::logo-agencia" title="Propietarios - Asesoría Inmobiliaria"> <div class="logo-border"></div> <img data-ondemand-img="https://st3.idealista.com/88/6b/1f/ipropietarios.gif" src="https://st1.idealista.com/static/common/img/icons/px.png" alt="Propietarios - Asesoría Inmobiliaria"> </a> </div> <a href="/inmueble/81531208/" class="item-link " title="Piso en calle Santa Florentina, 4, Casco Antiguo, Cartagena">Piso en calle Santa Florentina, 4, Casco Antiguo, Cartagena</a> <div class="row price-row clearfix"> <span class="item-price h2-simulated">110.000<span class="txt-big">€</span></span> </div> <span class="item-detail">1 <small>hab.</small></span> <span class="item-detail">59 <small>m²</small></span> <span class="item-detail">1ª <small>planta exterior con ascensor</small></span> <div class="item-description description"><p class="ellipsis">OBRA NUEVA EN PLENO CASCO HISTÓRICO DE CARTAGENA. BUENA OPCIÓN PARA INVERTIR. Viviendas tipo piso de 1 dorm. en pleno centro de Cartagena, con calidades de tipo alto, con fachada exterior con diseño innovador, y fachada a Sta. Florentina con limpieza y consolidación del ladrillo visto existente....</p></div> <div class="item-toolbar clearfix"> <div class="item-toolbar-contact"> <span class="icon-phone item-not-clickable-phone">868 863 364</span> <a class="icon-phone phone-btn item-clickable-phone" target="_blank" href="tel:868863364" data-xiti-markup='{ "click": {"xtPage":"listado::conversiones::contacto-por-telf","mustXtn2":true,"actionType":"PAGE"} }' data-xiti-page="telf_cliente_v"> <span>868 863 364</span> </a> <button class="icon-mail email-btn action-email fake-anchor"><span>Contactar</span></button> </div> <div class="item-toolbar-actions"> <button class="icon-fav favorite-btn action-fav fake-anchor" data-role="add" data-text-add="Guardar" data-text-remove="Quitar"> <span>Guardar</span> </button> <button class="icon-delete trash-btn action-discard fake-anchor" data-role="add" data-text-remove="Descartar" rel="nofollow"><span>Descartar</span></button> </div> </div> </div> </div> </div> </article> <article> <div class="item item_contains_branding" data-adid="39971746"> <div class="item-multimedia-container clearfix"> <div class="item-multimedia "> <div class="item-multimedia-features"> <span class="icon-plans"></span> </div> <div class="item-multimedia-pictures"> <span class="icon-photos"></span> <span data-count></span><span data-total>14</span> </div> <div class="item-ribbon-container"> </div> <span class="item-push-up txt-caption">Destacado</span> <div class="item-gallery"> <div class="gallery-fallback icon-no-pics"> <img data-ondemand-img="https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/d2/02/7f/270860355.jpg" src="https://st1.idealista.com/static/common/img/icons/px.png" class="vertical"> </div> </div> </div> <div class="item-info-container"> <div class="logo-branding"> <a href='/pro/ayala-y-asociados/' data-xiti-click="listado::logo-agencia" title="Ayala y asociados"> <div class="logo-border"></div> <img data-ondemand-img="https://st3.idealista.com/65/fb/2d/ayala-y-asociados.gif" src="https://st1.idealista.com/static/common/img/icons/px.png" alt="Ayala y asociados"> </a> </div> <a href="/inmueble/39971746/" class="item-link " title="Piso en calle Puertas de Murcia, Casco Antiguo, Cartagena">Piso en calle Puertas de Murcia, Casco Antiguo, Cartagena</a> <div class="row price-row clearfix"> <span class="item-price h2-simulated">227.000<span class="txt-big">€</span></span> </div> <span class="item-detail">2 <small>hab.</small></span> <span class="item-detail">83 <small>m²</small></span> <span class="item-detail">4ª <small>planta exterior con ascensor</small></span> <div class="item-description description"><p class="ellipsis">Este magnífico edificio es una muy buena opción de hacer realidad tus sueños. ¡Alberga hasta más de un centenar de Historia Viva Cartagenera! Si desea adquirir una propiedad en este histórico edificio puede gozar de innumerables privilegios; como son las extraordinarias vistas para todos los eve...</p></div> <div class="item-toolbar clearfix"> <div class="item-toolbar-contact"> <span class="icon-phone item-not-clickable-phone">968 913 766</span> <a class="icon-phone phone-btn item-clickable-phone" target="_blank" href="tel:968913766" data-xiti-markup='{ "click": {"xtPage":"listado::conversiones::contacto-por-telf","mustXtn2":true,"actionType":"PAGE"} }' data-xiti-page="telf_cliente_v"> <span>968 913 766</span> </a> <button class="icon-mail email-btn action-email fake-anchor"><span>Contactar</span></button> </div> <div class="item-toolbar-actions"> <button class="icon-fav favorite-btn action-fav fake-anchor" data-role="add" data-text-add="Guardar" data-text-remove="Quitar"> <span>Guardar</span> </button> <button class="icon-delete trash-btn action-discard fake-anchor" data-role="add" data-text-remove="Descartar" rel="nofollow"><span>Descartar</span></button> </div> </div> </div> </div> </div> </article> <article> <div class="item item_contains_branding" data-adid="38886278"> <div class="item-multimedia-container clearfix"> <div class="item-multimedia "> <div class="item-multimedia-features"> <span class="icon-plans"></span> </div> <div class="item-multimedia-pictures"> <span class="icon-photos"></span> <span data-count></span><span data-total>20</span> </div> <div class="item-ribbon-container"> </div> <span class="item-push-up txt-caption">Destacado</span> <div class="item-gallery"> <div class="gallery-fallback icon-no-pics"> <img data-ondemand-img="https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/60/4b/a0/574859016.jpg" src="https://st1.idealista.com/static/common/img/icons/px.png" class="vertical"> </div> </div> </div> <div class="item-info-container"> <div class="logo-branding"> <a href='/pro/alfainmobiliaria/' data-xiti-click="listado::logo-agencia" title="Alfa inmobiliaria"> <div class="logo-border"></div> <img data-ondemand-img="https://st3.idealista.com/6d/f6/9c/alfainmobiliaria.gif" src="https://st1.idealista.com/static/common/img/icons/px.png" alt="Alfa inmobiliaria"> </a> </div> <a href="/inmueble/38886278/" class="item-link " title="Piso en Casco Antiguo, Cartagena">Piso en Casco Antiguo, Cartagena</a> <div class="row price-row clearfix"> <span class="item-price h2-simulated">182.000<span class="txt-big">€</span></span> </div> <span class="item-detail">3 <small>hab.</small></span> <span class="item-detail">100 <small>m²</small></span> <span class="item-detail">2ª <small>planta exterior sin ascensor</small></span> <div class="item-description description"><p class="ellipsis">REF. 6624/364. Excelente oportunidad para vivir en pleno centro de Cartagena. Se vende piso 2ª planta, en conocido edificio, de excelente vecindad. Noventa metros distribuidos en tres dormitorios, salón comedor, amplia cocina y baño. Todo exterior con acceso a terraza corrida cubierta, parcialmen...</p></div> <div class="item-toolbar clearfix"> <div class="item-toolbar-contact"> <span class="icon-phone item-not-clickable-phone">968 140 492</span> <a class="icon-phone phone-btn item-clickable-phone" target="_blank" href="tel:968140492" data-xiti-markup='{ "click": {"xtPage":"listado::conversiones::contacto-por-telf","mustXtn2":true,"actionType":"PAGE"} }' data-xiti-page="telf_cliente_v"> <span>968 140 492</span> </a> <button class="icon-mail email-btn action-email fake-anchor"><span>Contactar</span></button> </div> <div class="item-toolbar-actions"> <button class="icon-fav favorite-btn action-fav fake-anchor" data-role="add" data-text-add="Guardar" data-text-remove="Quitar"> <span>Guardar</span> </button> <button class="icon-delete trash-btn action-discard fake-anchor" data-role="add" data-text-remove="Descartar" rel="nofollow"><span>Descartar</span></button> </div> </div> </div> </div> </div> </article> <article> <div class="item item_contains_branding" data-adid="40536729"> <div class="item-multimedia-container clearfix"> <div class="item-multimedia "> <div class="item-multimedia-features"> <span class="icon-plans"></span> </div> <div class="item-multimedia-pictures"> <span class="icon-photos"></span> <span data-count></span><span data-total>13</span> </div> <div class="item-ribbon-container"> </div> <span class="item-push-up txt-caption">Destacado</span> <div class="item-gallery"> <div class="gallery-fallback icon-no-pics"> <img data-ondemand-img="https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/74/ff/8e/284094093.jpg" src="https://st1.idealista.com/static/common/img/icons/px.png" class="vertical"> </div> </div> </div> <div class="item-info-container"> <div class="logo-branding"> <a href='/pro/ipropietarios/' data-xiti-click="listado::logo-agencia" title="Propietarios - Asesoría Inmobiliaria"> <div class="logo-border"></div> <img data-ondemand-img="https://st3.idealista.com/88/6b/1f/ipropietarios.gif" src="https://st1.idealista.com/static/common/img/icons/px.png" alt="Propietarios - Asesoría Inmobiliaria"> </a> </div> <a href="/inmueble/40536729/" class="item-link " title="Ático en calle Santa Florentina, 4, Casco Antiguo, Cartagena">Ático en calle Santa Florentina, 4, Casco Antiguo, Cartagena</a> <div class="row price-row clearfix"> <span class="item-price h2-simulated">360.000<span class="txt-big">€</span></span> </div> <span class="item-detail">4 <small>hab.</small></span> <span class="item-detail">147 <small>m²</small></span> <span class="item-detail">4ª <small>planta exterior con ascensor</small></span> <div class="item-description description"><p class="ellipsis">VIVIENDAS DE OBRA NUEVA EN PLENO CASCO HISTÓRICO DE CARTAGENA. El edificio consta de cuatro plantas, siendo la 4º denominada como ático, con posibilidad de buhardilla. Son algo más de 125 m² útiles, con estancias amplias y luminosas. Pavimento interior entre laminado flotante con varias opcione...</p></div> <div class="item-toolbar clearfix"> <div class="item-toolbar-contact"> <span class="icon-phone item-not-clickable-phone">868 863 364</span> <a class="icon-phone phone-btn item-clickable-phone" target="_blank" href="tel:868863364" data-xiti-markup='{ "click": {"xtPage":"listado::conversiones::contacto-por-telf","mustXtn2":true,"actionType":"PAGE"} }' data-xiti-page="telf_cliente_v"> <span>868 863 364</span> </a> <button class="icon-mail email-btn action-email fake-anchor"><span>Contactar</span></button> </div> <div class="item-toolbar-actions"> <button class="icon-fav favorite-btn action-fav fake-anchor" data-role="add" data-text-add="Guardar" data-text-remove="Quitar"> <span>Guardar</span> </button> <button class="icon-delete trash-btn action-discard fake-anchor" data-role="add" data-text-remove="Descartar" rel="nofollow"><span>Descartar</span></button> </div> </div> </div> </div> </div> </article> <article> <div class="item item_contains_branding" data-adid="39264056"> <div class="item-multimedia-container clearfix"> <div class="item-multimedia "> <div class="item-multimedia-pictures"> <span class="icon-photos"></span> <span data-count></span><span data-total>16</span> </div> <div class="item-ribbon-container"> </div> <span class="item-push-up txt-caption">Destacado</span> <div class="item-gallery"> <div class="gallery-fallback icon-no-pics"> <img data-ondemand-img="https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/80/e3/ef/582735767.jpg" src="https://st1.idealista.com/static/common/img/icons/px.png" class="vertical"> </div> </div> </div> <div class="item-info-container"> <div class="logo-branding"> <a href='/pro/cartagena-homes-inmobiliaria/' data-xiti-click="listado::logo-agencia" title="Cartagena Homes-Inmobiliaria"> <div class="logo-border"></div> <img data-ondemand-img="https://st3.idealista.com/da/35/2c/cartagena-homes-inmobiliaria.gif" src="https://st1.idealista.com/static/common/img/icons/px.png" alt="Cartagena Homes-Inmobiliaria"> </a> </div> <a href="/inmueble/39264056/" class="item-link " title="Piso en calle cañón, Casco Antiguo, Cartagena">Piso en calle cañón, Casco Antiguo, Cartagena</a> <div class="row price-row clearfix"> <span class="item-price h2-simulated">139.000<span class="txt-big">€</span></span> <span class="pricedown"> <span class="pricedown_price"> 149.000 € </span> <span class="pricedown_icon icon-pricedown">7%</span> </span> </div> <span class="item-detail">3 <small>hab.</small></span> <span class="item-detail">108 <small>m²</small></span> <span class="item-detail">4ª <small>planta exterior con ascensor</small></span> <div class="item-description description"><p class="ellipsis">Este piso se encuentra en Calle del Cañón, en pleno corazón de Cartagena, Murcia, situado en el Casco Antiguo de la ciudad, en la planta 4. Es un piso, construido en el año 1983, que tiene 108 m2 y dispone de 3 habitaciones y 2 baños, salon independiente, cocina y galería. una casa que te hará d...</p></div> <div class="item-toolbar clearfix"> <div class="item-toolbar-contact"> <span class="icon-phone item-not-clickable-phone">968 915 296</span> <a class="icon-phone phone-btn item-clickable-phone" target="_blank" href="tel:968915296" data-xiti-markup='{ "click": {"xtPage":"listado::conversiones::contacto-por-telf","mustXtn2":true,"actionType":"PAGE"} }' data-xiti-page="telf_cliente_v"> <span>968 915 296</span> </a> <button class="icon-mail email-btn action-email fake-anchor"><span>Contactar</span></button> </div> <div class="item-toolbar-actions"> <button class="icon-fav favorite-btn action-fav fake-anchor" data-role="add" data-text-add="Guardar" data-text-remove="Quitar"> <span>Guardar</span> </button> <button class="icon-delete trash-btn action-discard fake-anchor" data-role="add" data-text-remove="Descartar" rel="nofollow"><span>Descartar</span></button> </div> </div> </div> </div> </div> </article> <article> <div class="item item_contains_branding" data-adid="81614287"> <div class="item-multimedia-container clearfix"> <div class="item-multimedia "> <div class="item-multimedia-pictures"> <span class="icon-photos"></span> <span data-count></span><span data-total>34</span> </div> <div class="item-ribbon-container"> </div> <span class="item-push-up txt-caption">Destacado</span> <div class="item-gallery"> <div class="gallery-fallback icon-no-pics"> <img data-ondemand-img="https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/b1/3a/55/580650348.jpg" src="https://st1.idealista.com/static/common/img/icons/px.png" class="vertical"> </div> </div> </div> <div class="item-info-container"> <div class="logo-branding"> <a href='/pro/p29003309/' data-xiti-click="listado::logo-agencia" title="Inversa inmobiliaria"> <div class="logo-border"></div> <img data-ondemand-img="https://st3.idealista.com/7a/da/d9/p29003309.gif" src="https://st1.idealista.com/static/common/img/icons/px.png" alt="Inversa inmobiliaria"> </a> </div> <a href="/inmueble/81614287/" class="item-link " title="Piso en calle Palas, Casco Antiguo, Cartagena">Piso en calle Palas, Casco Antiguo, Cartagena</a> <div class="row price-row clearfix"> <span class="item-price h2-simulated">120.000<span class="txt-big">€</span></span> </div> <span class="item-detail">4 <small>hab.</small></span> <span class="item-detail">130 <small>m²</small></span> <span class="item-detail">1ª <small>planta exterior con ascensor</small></span> <div class="item-description description"><p class="ellipsis">CARTAGENA–CENTRO. CALLE PALAS, JUNTO HACIENDA. Situado en la zona más demandada y de moda en Cartagena, para ir a todos los sitios andando, sin perderte ni una sola de las actividades que se viven en nuestra ciudad. Una vivienda que te permitirá realizar una opción de proyecto escogida totalment...</p></div> <div class="item-toolbar clearfix"> <div class="item-toolbar-contact"> <span class="icon-phone item-not-clickable-phone">868 860 183</span> <a class="icon-phone phone-btn item-clickable-phone" target="_blank" href="tel:868860183" data-xiti-markup='{ "click": {"xtPage":"listado::conversiones::contacto-por-telf","mustXtn2":true,"actionType":"PAGE"} }' data-xiti-page="telf_cliente_v"> <span>868 860 183</span> </a> <button class="icon-mail email-btn action-email fake-anchor"><span>Contactar</span></button> </div> <div class="item-toolbar-actions"> <button class="icon-fav favorite-btn action-fav fake-anchor" data-role="add" data-text-add="Guardar" data-text-remove="Quitar"> <span>Guardar</span> </button> <button class="icon-delete trash-btn action-discard fake-anchor" data-role="add" data-text-remove="Descartar" rel="nofollow"><span>Descartar</span></button> </div> </div> </div> </div> </div> </article> <article> <div class="item item_contains_branding" data-adid="81591831"> <div class="item-multimedia-container clearfix"> <div class="item-multimedia "> <div class="item-multimedia-pictures"> <span class="icon-photos"></span> <span data-count></span><span data-total>20</span> </div> <div class="item-ribbon-container"> </div> <span class="item-push-up txt-caption">Destacado</span> <div class="item-gallery"> <div class="gallery-fallback icon-no-pics"> <img data-ondemand-img="https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/ef/57/a4/580209684.jpg" src="https://st1.idealista.com/static/common/img/icons/px.png" class="vertical"> </div> </div> </div> <div class="item-info-container"> <div class="logo-branding"> <a href='/pro/cartagena-homes-inmobiliaria/' data-xiti-click="listado::logo-agencia" title="Cartagena Homes-Inmobiliaria"> <div class="logo-border"></div> <img data-ondemand-img="https://st3.idealista.com/da/35/2c/cartagena-homes-inmobiliaria.gif" src="https://st1.idealista.com/static/common/img/icons/px.png" alt="Cartagena Homes-Inmobiliaria"> </a> </div> <a href="/inmueble/81591831/" class="item-link " title="Piso en calle Don Matías, Casco Antiguo, Cartagena">Piso en calle Don Matías, Casco Antiguo, Cartagena</a> <div class="row price-row clearfix"> <span class="item-price h2-simulated">145.000<span class="txt-big">€</span></span> <span class="item-parking">Garaje incluido</span> </div> <span class="item-detail">3 <small>hab.</small></span> <span class="item-detail">107 <small>m²</small></span> <span class="item-detail">Bajo <small>exterior con ascensor</small></span> <div class="item-description description"><p class="ellipsis">Este piso se encuentra en Calle Don Matías, 30202, Cartagena, Murcia, en la zona del Barrio Universitario, en planta baja. Es un piso, construido en el año 2006, que tiene 107 m2 de los cuales 85 m2 son útiles y dispone de 3 habitaciones y 2 baños. Se trata de un piso exterior con 3 dormitorios,...</p></div> <div class="item-toolbar clearfix"> <div class="item-toolbar-contact"> <span class="icon-phone item-not-clickable-phone">968 915 296</span> <a class="icon-phone phone-btn item-clickable-phone" target="_blank" href="tel:968915296" data-xiti-markup='{ "click": {"xtPage":"listado::conversiones::contacto-por-telf","mustXtn2":true,"actionType":"PAGE"} }' data-xiti-page="telf_cliente_v"> <span>968 915 296</span> </a> <button class="icon-mail email-btn action-email fake-anchor"><span>Contactar</span></button> </div> <div class="item-toolbar-actions"> <button class="icon-fav favorite-btn action-fav fake-anchor" data-role="add" data-text-add="Guardar" data-text-remove="Quitar"> <span>Guardar</span> </button> <button class="icon-delete trash-btn action-discard fake-anchor" data-role="add" data-text-remove="Descartar" rel="nofollow"><span>Descartar</span></button> </div> </div> </div> </div> </div> </article> <article> <div class="item item_contains_branding" data-adid="39743927"> <div class="item-multimedia-container clearfix"> <div class="item-multimedia "> <div class="item-multimedia-pictures"> <span class="icon-photos"></span> <span data-count></span><span data-total>35</span> </div> <div class="item-ribbon-container"> </div> <span class="item-push-up txt-caption">Destacado</span> <div class="item-gallery"> <div class="gallery-fallback icon-no-pics"> <img data-ondemand-img="https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/f7/30/b9/281240198.jpg" src="https://st1.idealista.com/static/common/img/icons/px.png" class="vertical"> </div> </div> </div> <div class="item-info-container"> <div class="logo-branding"> <a href='/pro/cartagena-homes-inmobiliaria/' data-xiti-click="listado::logo-agencia" title="Cartagena Homes-Inmobiliaria"> <div class="logo-border"></div> <img data-ondemand-img="https://st3.idealista.com/da/35/2c/cartagena-homes-inmobiliaria.gif" src="https://st1.idealista.com/static/common/img/icons/px.png" alt="Cartagena Homes-Inmobiliaria"> </a> </div> <a href="/inmueble/39743927/" class="item-link " title="Piso en calle capitanes ripoll, Casco Antiguo, Cartagena">Piso en calle capitanes ripoll, Casco Antiguo, Cartagena</a> <div class="row price-row clearfix"> <span class="item-price h2-simulated">130.000<span class="txt-big">€</span></span> </div> <span class="item-detail">5 <small>hab.</small></span> <span class="item-detail">143 <small>m²</small></span> <span class="item-detail">Bajo <small>exterior con ascensor</small></span> <div class="item-description description"><p class="ellipsis">Propiedad ubicada en la Calle Capitanes Ripoll de Cartagena, a un paso de las universidades tanto de la Muralla del Mar como del Paseo Alfonso XIII. Accedemos a la vivienda a través del recibidor, a mano derecha encontramos el salon comedor y a mano izquierda la cocina con muchas posibilidades d...</p></div> <div class="item-toolbar clearfix"> <div class="item-toolbar-contact"> <span class="icon-phone item-not-clickable-phone">968 915 296</span> <a class="icon-phone phone-btn item-clickable-phone" target="_blank" href="tel:968915296" data-xiti-markup='{ "click": {"xtPage":"listado::conversiones::contacto-por-telf","mustXtn2":true,"actionType":"PAGE"} }' data-xiti-page="telf_cliente_v"> <span>968 915 296</span> </a> <button class="icon-mail email-btn action-email fake-anchor"><span>Contactar</span></button> </div> <div class="item-toolbar-actions"> <button class="icon-fav favorite-btn action-fav fake-anchor" data-role="add" data-text-add="Guardar" data-text-remove="Quitar"> <span>Guardar</span> </button> <button class="icon-delete trash-btn action-discard fake-anchor" data-role="add" data-text-remove="Descartar" rel="nofollow"><span>Descartar</span></button> </div> </div> </div> </div> </div> </article> <article> <div class="item item_contains_branding" data-adid="30889326"> <div class="item-multimedia-container clearfix"> <div class="item-multimedia "> <div class="item-multimedia-pictures"> <span class="icon-photos"></span> <span data-count></span><span data-total>24</span> </div> <div class="item-ribbon-container"> </div> <span class="item-push-up txt-caption">Destacado</span> <div class="item-gallery"> <div class="gallery-fallback icon-no-pics"> <img data-ondemand-img="https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/62/d0/d1/107697109.jpg" src="https://st1.idealista.com/static/common/img/icons/px.png" class="vertical"> </div> </div> </div> <div class="item-info-container"> <div class="logo-branding"> <a href='/pro/ipropietarios/' data-xiti-click="listado::logo-agencia" title="Propietarios - Asesoría Inmobiliaria"> <div class="logo-border"></div> <img data-ondemand-img="https://st3.idealista.com/88/6b/1f/ipropietarios.gif" src="https://st1.idealista.com/static/common/img/icons/px.png" alt="Propietarios - Asesoría Inmobiliaria"> </a> </div> <a href="/inmueble/30889326/" class="item-link " title="Piso en Casco Antiguo, Cartagena">Piso en Casco Antiguo, Cartagena</a> <div class="row price-row clearfix"> <span class="item-price h2-simulated">280.000<span class="txt-big">€</span></span> </div> <span class="item-detail">4 <small>hab.</small></span> <span class="item-detail">180 <small>m²</small></span> <span class="item-detail">1ª <small>planta exterior con ascensor</small></span> <div class="item-description description"><p class="ellipsis">Estupenda vivienda situada en un edificio de referencia en Cartagena 180 m2 construidos, cuatro dormitorios dos baños, uno de ellos en suite, reformado totalmente, el otro baño esta para actualizar, armarios empotrados, suelo de parquet en toda la vivienda, amplio salón con balcón de gran tamaño...</p></div> <div class="item-toolbar clearfix"> <div class="item-toolbar-contact"> <span class="icon-phone item-not-clickable-phone">868 863 364</span> <a class="icon-phone phone-btn item-clickable-phone" target="_blank" href="tel:868863364" data-xiti-markup='{ "click": {"xtPage":"listado::conversiones::contacto-por-telf","mustXtn2":true,"actionType":"PAGE"} }' data-xiti-page="telf_cliente_v"> <span>868 863 364</span> </a> <button class="icon-mail email-btn action-email fake-anchor"><span>Contactar</span></button> </div> <div class="item-toolbar-actions"> <button class="icon-fav favorite-btn action-fav fake-anchor" data-role="add" data-text-add="Guardar" data-text-remove="Quitar"> <span>Guardar</span> </button> <button class="icon-delete trash-btn action-discard fake-anchor" data-role="add" data-text-remove="Descartar" rel="nofollow"><span>Descartar</span></button> </div> </div> </div> </div> </div> </article> <article> <div class="item item_contains_branding" data-adid="37484135"> <div class="item-multimedia-container clearfix"> <div class="item-multimedia "> <div class="item-multimedia-features"> <span class="icon-plans"></span> </div> <div class="item-multimedia-pictures"> <span class="icon-photos"></span> <span data-count></span><span data-total>20</span> </div> <div class="item-ribbon-container"> </div> <span class="item-push-up txt-caption">Destacado</span> <div class="item-gallery"> <div class="gallery-fallback icon-no-pics"> <img data-ondemand-img="https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/f4/e0/09/274535167.jpg" src="https://st1.idealista.com/static/common/img/icons/px.png" class="vertical"> </div> </div> </div> <div class="item-info-container"> <div class="logo-branding"> <a href='/pro/alfainmobiliaria/' data-xiti-click="listado::logo-agencia" title="Alfa inmobiliaria"> <div class="logo-border"></div> <img data-ondemand-img="https://st3.idealista.com/6d/f6/9c/alfainmobiliaria.gif" src="https://st1.idealista.com/static/common/img/icons/px.png" alt="Alfa inmobiliaria"> </a> </div> <a href="/inmueble/37484135/" class="item-link " title="Piso en Casco Antiguo, Cartagena">Piso en Casco Antiguo, Cartagena</a> <div class="row price-row clearfix"> <span class="item-price h2-simulated">173.000<span class="txt-big">€</span></span> </div> <span class="item-detail">2 <small>hab.</small></span> <span class="item-detail">82 <small>m²</small></span> <span class="item-detail"> <small> sin ascensor</small></span> <div class="item-description description"><p class="ellipsis">REF. 6624/329. Piso reformado en edificio antiguo en el centro de la ciudad de Cartagena. Muy luminoso, todo exterior y con todas las comodidades. Zona tranquila.</p></div> <div class="item-toolbar clearfix"> <div class="item-toolbar-contact"> <span class="icon-phone item-not-clickable-phone">968 140 492</span> <a class="icon-phone phone-btn item-clickable-phone" target="_blank" href="tel:968140492" data-xiti-markup='{ "click": {"xtPage":"listado::conversiones::contacto-por-telf","mustXtn2":true,"actionType":"PAGE"} }' data-xiti-page="telf_cliente_v"> <span>968 140 492</span> </a> <button class="icon-mail email-btn action-email fake-anchor"><span>Contactar</span></button> </div> <div class="item-toolbar-actions"> <button class="icon-fav favorite-btn action-fav fake-anchor" data-role="add" data-text-add="Guardar" data-text-remove="Quitar"> <span>Guardar</span> </button> <button class="icon-delete trash-btn action-discard fake-anchor" data-role="add" data-text-remove="Descartar" rel="nofollow"><span>Descartar</span></button> </div> </div> </div> </div> </div> </article> <article> <div class="item item_contains_branding" data-adid="40070899"> <div class="item-multimedia-container clearfix"> <div class="item-multimedia "> <div class="item-multimedia-pictures"> <span class="icon-photos"></span> <span data-count></span><span data-total>20</span> </div> <div class="item-ribbon-container"> </div> <span class="item-push-up txt-caption">Destacado</span> <div class="item-gallery"> <div class="gallery-fallback icon-no-pics"> <img data-ondemand-img="https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/f8/ab/e3/273370617.jpg" src="https://st1.idealista.com/static/common/img/icons/px.png" class="vertical"> </div> </div> </div> <div class="item-info-container"> <div class="logo-branding"> <a href='/pro/ipropietarios/' data-xiti-click="listado::logo-agencia" title="Propietarios - Asesoría Inmobiliaria"> <div class="logo-border"></div> <img data-ondemand-img="https://st3.idealista.com/88/6b/1f/ipropietarios.gif" src="https://st1.idealista.com/static/common/img/icons/px.png" alt="Propietarios - Asesoría Inmobiliaria"> </a> </div> <a href="/inmueble/40070899/" class="item-link " title="Estudio en Casco Antiguo, Cartagena">Estudio en Casco Antiguo, Cartagena</a> <div class="row price-row clearfix"> <span class="item-price h2-simulated">165.000<span class="txt-big">€</span></span> </div> <span class="item-detail">105 <small>m²</small></span> <span class="item-detail">1ª <small>planta exterior con ascensor</small></span> <div class="item-description description"><p class="ellipsis">No pierdas esta oportunidad, y múdate al centro reformando esta vivienda, de 105 metros, con dos baños, y vista de 3 balcones a santa florentina y dos hacia el cerro del molinete, con bonitas vistas. ¡Entra mucha luz, y haciendo una reforma se quedaría la casa de tus sueños! Esta diáfano, para po...</p></div> <div class="item-toolbar clearfix"> <div class="item-toolbar-contact"> <span class="icon-phone item-not-clickable-phone">868 863 364</span> <a class="icon-phone phone-btn item-clickable-phone" target="_blank" href="tel:868863364" data-xiti-markup='{ "click": {"xtPage":"listado::conversiones::contacto-por-telf","mustXtn2":true,"actionType":"PAGE"} }' data-xiti-page="telf_cliente_v"> <span>868 863 364</span> </a> <button class="icon-mail email-btn action-email fake-anchor"><span>Contactar</span></button> </div> <div class="item-toolbar-actions"> <button class="icon-fav favorite-btn action-fav fake-anchor" data-role="add" data-text-add="Guardar" data-text-remove="Quitar"> <span>Guardar</span> </button> <button class="icon-delete trash-btn action-discard fake-anchor" data-role="add" data-text-remove="Descartar" rel="nofollow"><span>Descartar</span></button> </div> </div> </div> </div> </div> </article> <article> <div class="item item_contains_branding" data-adid="40041910"> <div class="item-multimedia-container clearfix"> <div class="item-multimedia "> <div class="item-multimedia-pictures"> <span class="icon-photos"></span> <span data-count></span><span data-total>11</span> </div> <div class="item-ribbon-container"> </div> <span class="item-push-up txt-caption">Destacado</span> <div class="item-gallery"> <div class="gallery-fallback icon-no-pics"> <img data-ondemand-img="https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/22/cf/e3/284088604.jpg" src="https://st1.idealista.com/static/common/img/icons/px.png" class="vertical"> </div> </div> </div> <div class="item-info-container"> <div class="logo-branding"> <a href='/pro/ipropietarios/' data-xiti-click="listado::logo-agencia" title="Propietarios - Asesoría Inmobiliaria"> <div class="logo-border"></div> <img data-ondemand-img="https://st3.idealista.com/88/6b/1f/ipropietarios.gif" src="https://st1.idealista.com/static/common/img/icons/px.png" alt="Propietarios - Asesoría Inmobiliaria"> </a> </div> <a href="/inmueble/40041910/" class="item-link " title="Piso en calle Santa Florentina, 4, Casco Antiguo, Cartagena">Piso en calle Santa Florentina, 4, Casco Antiguo, Cartagena</a> <div class="row price-row clearfix"> <span class="item-price h2-simulated">285.000<span class="txt-big">€</span></span> </div> <span class="item-detail">3 <small>hab.</small></span> <span class="item-detail">123 <small>m²</small></span> <span class="item-detail">2ª <small>planta exterior con ascensor</small></span> <div class="item-description description"><p class="ellipsis">UNA VIVIENDA EN PLENO CENTRO DEL CASCO HISTÓRICO DE CARTAGENA. Viviendas tipo piso de 3 dorm. en pleno centro de Cartagena, con calidades de tipo alto, con fachada exterior con diseño innovador, y fachada a Sta. Florentina con limpieza y consolidación del ladrillo visto existente. Son algo más d...</p></div> <div class="item-toolbar clearfix"> <div class="item-toolbar-contact"> <span class="icon-phone item-not-clickable-phone">868 863 364</span> <a class="icon-phone phone-btn item-clickable-phone" target="_blank" href="tel:868863364" data-xiti-markup='{ "click": {"xtPage":"listado::conversiones::contacto-por-telf","mustXtn2":true,"actionType":"PAGE"} }' data-xiti-page="telf_cliente_v"> <span>868 863 364</span> </a> <button class="icon-mail email-btn action-email fake-anchor"><span>Contactar</span></button> </div> <div class="item-toolbar-actions"> <button class="icon-fav favorite-btn action-fav fake-anchor" data-role="add" data-text-add="Guardar" data-text-remove="Quitar"> <span>Guardar</span> </button> <button class="icon-delete trash-btn action-discard fake-anchor" data-role="add" data-text-remove="Descartar" rel="nofollow"><span>Descartar</span></button> </div> </div> </div> </div> </div> </article> <article> <div class="item item_contains_branding" data-adid="40036825"> <div class="item-multimedia-container clearfix"> <div class="item-multimedia "> <div class="item-multimedia-pictures"> <span class="icon-photos"></span> <span data-count></span><span data-total>35</span> </div> <div class="item-ribbon-container"> </div> <span class="item-push-up txt-caption">Destacado</span> <div class="item-gallery"> <div class="gallery-fallback icon-no-pics"> <img data-ondemand-img="https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/88/e4/cb/272274468.jpg" src="https://st1.idealista.com/static/common/img/icons/px.png" class="vertical"> </div> </div> </div> <div class="item-info-container"> <div class="logo-branding"> <a href='/pro/ipropietarios/' data-xiti-click="listado::logo-agencia" title="Propietarios - Asesoría Inmobiliaria"> <div class="logo-border"></div> <img data-ondemand-img="https://st3.idealista.com/88/6b/1f/ipropietarios.gif" src="https://st1.idealista.com/static/common/img/icons/px.png" alt="Propietarios - Asesoría Inmobiliaria"> </a> </div> <a href="/inmueble/40036825/" class="item-link " title="Piso en Casco Antiguo, Cartagena">Piso en Casco Antiguo, Cartagena</a> <div class="row price-row clearfix"> <span class="item-price h2-simulated">370.000<span class="txt-big">€</span></span> </div> <span class="item-detail">6 <small>hab.</small></span> <span class="item-detail">240 <small>m²</small></span> <span class="item-detail">15ª <small>planta exterior con ascensor</small></span> <div class="item-description description"><p class="ellipsis">Piso de 240 m² con 6 dormitorios (uno de servicio), con 3 baños. Grandes dimensiones en todas las estancias con amplias posibilidades de reforma por su buena distribución. Una vivienda por su altura con gran luminosidad y con tres orientaciones. Una cocina de unos 30 m² con galería y zona de serv...</p></div> <div class="item-toolbar clearfix"> <div class="item-toolbar-contact"> <span class="icon-phone item-not-clickable-phone">868 863 364</span> <a class="icon-phone phone-btn item-clickable-phone" target="_blank" href="tel:868863364" data-xiti-markup='{ "click": {"xtPage":"listado::conversiones::contacto-por-telf","mustXtn2":true,"actionType":"PAGE"} }' data-xiti-page="telf_cliente_v"> <span>868 863 364</span> </a> <button class="icon-mail email-btn action-email fake-anchor"><span>Contactar</span></button> </div> <div class="item-toolbar-actions"> <button class="icon-fav favorite-btn action-fav fake-anchor" data-role="add" data-text-add="Guardar" data-text-remove="Quitar"> <span>Guardar</span> </button> <button class="icon-delete trash-btn action-discard fake-anchor" data-role="add" data-text-remove="Descartar" rel="nofollow"><span>Descartar</span></button> </div> </div> </div> </div> </div> </article> <article> <div class="item item_contains_branding item_featured item_highlight-phrase" data-adid="39994336"> <div class="item-highlight-phrase">Piso en pleno centro en Edificio del Teatro Circo</div> <div class="item-multimedia-container clearfix"> <div class="item-multimedia "> <div class="item-multimedia-pictures"> <span class="icon-photos"></span> <span data-count></span><span data-total>19</span> </div> <div class="item-ribbon-container"> </div> <span class="item-push-up txt-caption">Destacado</span> <div class="item-gallery"> <div class="gallery-fallback icon-no-pics"> <img data-ondemand-img="https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/e9/a8/66/271380827.jpg" src="https://st1.idealista.com/static/common/img/icons/px.png" class="vertical"> </div> </div> </div> <div class="item-info-container"> <div class="logo-branding"> <a href='/pro/cartagena-homes-inmobiliaria/' data-xiti-click="listado::logo-agencia" title="Cartagena Homes-Inmobiliaria"> <div class="logo-border"></div> <img data-ondemand-img="https://st3.idealista.com/da/35/2c/cartagena-homes-inmobiliaria.gif" src="https://st1.idealista.com/static/common/img/icons/px.png" alt="Cartagena Homes-Inmobiliaria"> </a> </div> <a href="/inmueble/39994336/" class="item-link " title="Piso en calle tolosa latour, Casco Antiguo, Cartagena">Piso en calle tolosa latour, Casco Antiguo, Cartagena</a> <div class="row price-row clearfix"> <span class="item-price h2-simulated">147.000<span class="txt-big">€</span></span> </div> <span class="item-detail">3 <small>hab.</small></span> <span class="item-detail">100 <small>m²</small></span> <span class="item-detail">2ª <small>planta exterior con ascensor</small></span> <div class="item-description description"><p class="ellipsis">Esta vivienda esta situada en Calle Tolosa Latour, en pleno centro de Cartagena. Ubicado en el edificio Cartago Nova, dispone de 109m2 de parcela divididos en tres dormitorios y un cuarto de baño. Al entrar a la vivienda encontramos a mano derecha la primera habitación, unos pasos mas adelante en...</p></div> <div class="item-toolbar clearfix"> <div class="item-toolbar-contact"> <span class="icon-phone item-not-clickable-phone">968 915 296</span> <a class="icon-phone phone-btn item-clickable-phone" target="_blank" href="tel:968915296" data-xiti-markup='{ "click": {"xtPage":"listado::conversiones::contacto-por-telf","mustXtn2":true,"actionType":"PAGE"} }' data-xiti-page="telf_cliente_v"> <span>968 915 296</span> </a> <button class="icon-mail email-btn action-email fake-anchor"><span>Contactar</span></button> </div> <div class="item-toolbar-actions"> <button class="icon-fav favorite-btn action-fav fake-anchor" data-role="add" data-text-add="Guardar" data-text-remove="Quitar"> <span>Guardar</span> </button> <button class="icon-delete trash-btn action-discard fake-anchor" data-role="add" data-text-remove="Descartar" rel="nofollow"><span>Descartar</span></button> </div> </div> </div> </div> </div> </article> <article> <div class="item item_contains_branding" data-adid="40498317"> <div class="item-multimedia-container clearfix"> <div class="item-multimedia "> <div class="item-multimedia-pictures"> <span class="icon-photos"></span> <span data-count></span><span data-total>14</span> </div> <div class="item-ribbon-container"> </div> <span class="item-push-up txt-caption">Destacado</span> <div class="item-gallery"> <div class="gallery-fallback icon-no-pics"> <img data-ondemand-img="https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/19/50/aa/282532300.jpg" src="https://st1.idealista.com/static/common/img/icons/px.png" class="vertical"> </div> </div> </div> <div class="item-info-container"> <div class="logo-branding"> <a href='/pro/siemprecasas/' data-xiti-click="listado::logo-agencia" title="SiempreCasas"> <div class="logo-border"></div> <img data-ondemand-img="https://st3.idealista.com/b8/a4/59/siemprecasas.gif" src="https://st1.idealista.com/static/common/img/icons/px.png" alt="SiempreCasas"> </a> </div> <a href="/inmueble/40498317/" class="item-link " title="Ático en Carlos III, Casco Antiguo, Cartagena">Ático en Carlos III, Casco Antiguo, Cartagena</a> <div class="row price-row clearfix"> <span class="item-price h2-simulated">240.000<span class="txt-big">€</span></span> <span class="item-parking">Garaje incluido</span> </div> <span class="item-detail">3 <small>hab.</small></span> <span class="item-detail">128 <small>m²</small></span> <span class="item-detail">5ª <small>planta exterior con ascensor</small></span> <div class="item-description description"><p class="ellipsis">! ESPECTACULAR ATICO, NUEVO A ESTRENAR! . RECIÉN REBAJADO. Situado en una de las mejores zonas de Cartagena y más demandadas. Rodeado de todos los servicios. Exterior y muy luminoso. Dispone de tres habitaciones. Dos baños. Gran salón con acceso a la terraza-solarium. Suelos de mármol. Ventanas d...</p></div> <div class="item-toolbar clearfix"> <div class="item-toolbar-contact"> <span class="icon-phone item-not-clickable-phone">968 914 469</span> <a class="icon-phone phone-btn item-clickable-phone" target="_blank" href="tel:968914469" data-xiti-markup='{ "click": {"xtPage":"listado::conversiones::contacto-por-telf","mustXtn2":true,"actionType":"PAGE"} }' data-xiti-page="telf_cliente_v"> <span>968 914 469</span> </a> <button class="icon-mail email-btn action-email fake-anchor"><span>Contactar</span></button> </div> <div class="item-toolbar-actions"> <button class="icon-fav favorite-btn action-fav fake-anchor" data-role="add" data-text-add="Guardar" data-text-remove="Quitar"> <span>Guardar</span> </button> <button class="icon-delete trash-btn action-discard fake-anchor" data-role="add" data-text-remove="Descartar" rel="nofollow"><span>Descartar</span></button> </div> </div> </div> </div> </div> </article> <article> <div class="item item_contains_branding" data-adid="37158661"> <div class="item-multimedia-container clearfix"> <div class="item-multimedia "> <div class="item-multimedia-pictures"> <span class="icon-photos"></span> <span data-count></span><span data-total>13</span> </div> <div class="item-ribbon-container"> </div> <span class="item-push-up txt-caption">Destacado</span> <div class="item-gallery"> <div class="gallery-fallback icon-no-pics"> <img data-ondemand-img="https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/c2/54/0c/211768829.jpg" src="https://st1.idealista.com/static/common/img/icons/px.png" class="vertical"> </div> </div> </div> <div class="item-info-container"> <div class="logo-branding"> <a href='/pro/siemprecasas/' data-xiti-click="listado::logo-agencia" title="SiempreCasas"> <div class="logo-border"></div> <img data-ondemand-img="https://st3.idealista.com/b8/a4/59/siemprecasas.gif" src="https://st1.idealista.com/static/common/img/icons/px.png" alt="SiempreCasas"> </a> </div> <a href="/inmueble/37158661/" class="item-link " title="Piso en Calle Jabonerías, Casco Antiguo, Cartagena">Piso en Calle Jabonerías, Casco Antiguo, Cartagena</a> <div class="row price-row clearfix"> <span class="item-price h2-simulated">145.000<span class="txt-big">€</span></span> </div> <span class="item-detail">2 <small>hab.</small></span> <span class="item-detail">89 <small>m²</small></span> <span class="item-detail">3ª <small>planta exterior con ascensor</small></span> <div class="item-description description"><p class="ellipsis">! REBAJADA DE PRECIO! . ESTUPENDA VIVIENDA EN PLENO CENTRO DE CARTAGENA. EN PUERTAS DE MURCIA. VIVIENDA SEMINUEVA. Ubicación inmejorable (junto plaza icue). Dispone de dos habitaciones. Dos baños. Cocina seminueva totalmente equipada. Pintura lisa. Aire acondicionado por conductos. Calefacción. S...</p></div> <div class="item-toolbar clearfix"> <div class="item-toolbar-contact"> <span class="icon-phone item-not-clickable-phone">968 914 469</span> <a class="icon-phone phone-btn item-clickable-phone" target="_blank" href="tel:968914469" data-xiti-markup='{ "click": {"xtPage":"listado::conversiones::contacto-por-telf","mustXtn2":true,"actionType":"PAGE"} }' data-xiti-page="telf_cliente_v"> <span>968 914 469</span> </a> <button class="icon-mail email-btn action-email fake-anchor"><span>Contactar</span></button> </div> <div class="item-toolbar-actions"> <button class="icon-fav favorite-btn action-fav fake-anchor" data-role="add" data-text-add="Guardar" data-text-remove="Quitar"> <span>Guardar</span> </button> <button class="icon-delete trash-btn action-discard fake-anchor" data-role="add" data-text-remove="Descartar" rel="nofollow"><span>Descartar</span></button> </div> </div> </div> </div> </div> </article> <p class="items-average-price">Precio medio 1.569 eur/m²</p> <div class="pagination"> <ul> <li class="moreresults"><span>Más resultados:</span></li><li class="selected"><span>1</span></li><li><a class="" href="/venta-viviendas/cartagena/cartagena/casco-antiguo/pagina-2.htm">2</a></li><li><a class="" href="/venta-viviendas/cartagena/cartagena/casco-antiguo/pagina-3.htm">3</a></li><li><a class="" href="/venta-viviendas/cartagena/cartagena/casco-antiguo/pagina-4.htm">4</a></li><li><a class="" href="/venta-viviendas/cartagena/cartagena/casco-antiguo/pagina-5.htm">5</a></li><li><a class="" href="/venta-viviendas/cartagena/cartagena/casco-antiguo/pagina-6.htm">6</a></li><li class="next"><a class="icon-arrow-right-after" href="/venta-viviendas/cartagena/cartagena
	var smartBannerConfig={locale:"es",userAuthenticated:false,urls:{urlLegalNotice:"/info/politica-cookies"}};
</script> <script type="text/javascript">

	var communicatorConfig={enabled:true,endPointURL:"//commt.idealista.com",authCookieName:"cc",refreshTokenURL:"/communicator/refresh-token.ajax"};

</script> <script>
	var config={locale:"es",userAuthenticated:false,favoriteFirstTime:true,discardFirstTime:true,urlAddFavorite:"/add-favorite.htm",addFavoriteTargetId:"16",urlRemoveFavorite:"/remove-favorite.htm",urlAddDiscarded:"/add-ruled-out-web-listing.htm",urlRemoveDiscarded:"/remove-ruled-out.htm",urlAddComment:"/update-favorite-comment.htm",urlContact:"/ajax/contact/11/sendcontact.ajax",urlListingContact:"/ajax/contact/11/sendcontact.ajax",urlGalleryContact:"/ajax/contact/37/sendcontact.ajax",urlCounterOffer:"/ajax/contact/suggested/sendcontact.ajax",urlSuggestedAgencies:"/ajax/zoneexperts/suggested/11/sendcontact.ajax",urlReloadCaptcha:"/ajax/captcha/reloadCaptcha.ajax",urlAdContactInfo:"/ajax/listingController/adContactInfo.ajax",urlAdNewContactInfo:"/ajax/listingController/adContactInfoForListing.ajax",mediaTablet:"screen and (max-width: 1023px) and (min-width: 768px)",mediaMobile:"screen and (max-width: 767px)",mediaDesktop:"screen and (min-width: 1023px)",listAction:"/ajax/listingcontroller/listingajax.ajax",typology:"1",operation:"1",locationUri:"cartagena/cartagena/casco-antiguo",urlAddDeferredDiscarded:"/add-deferred-ruled-out.htm",mapSearchUrl:"/venta-viviendas/cartagena/cartagena/casco-antiguo/mapa-google",listingSearchUrl:"/venta-viviendas/cartagena/cartagena/casco-antiguo/",imageSizes:{"1280X400":80,"140X105":80,"140":80,"300":85,"600":80,"850":80,"1500":80,"250X188":80,"500X375":80,"300X225":80,"600X450":80},mapMode:false,showPopupOnClickingDetail:true,saveAlertPopupCookieName:"askToSaveAlertPopUp",urlSavedAdsListing:"/favoritos/venta-viviendas/cartagena/cartagena/casco-antiguo/",urlSearchTotals:"/ajax/listingcontroller/totals/listingajax.ajax",searchWithoutFilters:"true",xitiClientMarkup:{listingFavoritesTabLink:"listado::click-a-favoritos",listingGalleryContactButton:"listado::galeria::boton-contactar",listingGalleryLinkDetail:"listado::galeria::enlace-detalle",listingContactLink:"listado::conversiones::form_contacto",listingGalleryContactLink:"listado::conversiones::form-contacto-galeria",listingFavoritesLoginInPlace:"listado::conversiones::login-favoritear-inplace",listingRuledOutLoginInPlace:"listado::conversiones::login-descartar-inplace"},maxAdContactMessagesSuggested:3,changeListingType:"/es/ajax/listingcontroller/changeMode.ajax",listingType:"1",urlShapeValidation:"/es/ajax/listingcontroller/validateshape.ajax",liveSearchMapZoom:"",liveSearchMapNorthEast:"",liveSearchMapSouth
src:"https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/68/50/2a/282532294.jpg",width:596,height:427},{multimediaId:282532314,src:"https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/69/da/02/282532314.jpg",width:597,height:428},{multimediaId:282532273,src:"https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/8a/1c/dc/282532273.jpg",width:600,height:450},{multimediaId:282532073,src:"https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/94/0a/b2/282532073.jpg",width:596,height:427},{multimediaId:282532020,src:"https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/bb/74/2e/282532020.jpg",width:600,height:450},{multimediaId:282532012,src:"https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/9c/0a/e8/282532012.jpg",width:600,height:450}],"37158661":[{multimediaId:211768829,src:"https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/c2/54/0c/211768829.jpg",width:480,height:320},{multimediaId:211768832,src:"https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/69/c1/ab/211768832.jpg",width:480,height:320},{multimediaId:211768987,src:"https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/d6/85/bc/211768987.jpg",width:480,height:320},{multimediaId:211769000,src:"https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/03/e5/66/211769000.jpg",width:480,height:320},{multimediaId:211769005,src:"https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/4b/3d/62/211769005.jpg",width:480,height:320},{multimediaId:211769035,src:"https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/04/f7/ec/211769035.jpg",width:480,height:320},{multimediaId:211769055,src:"https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/06/3c/4a/211769055.jpg",width:480,height:320},{multimediaId:211769213,src:"https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/84/03/3d/211769213.jpg",width:480,height:320},{multimediaId:211769214,src:"https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/33/1a/78/211769214.jpg",width:480,height:320},{multimediaId:211769228,src:"https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/80/98/c0/211769228.jpg",width:480,height:320},{multimediaId:211769238,src:"https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/18/d4/01/211769238.jpg",width:480,height:320},{multimediaId:211769240,src:"https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/d2/f4/d7/211769240.jpg",width:480,height:320},{multimediaId:211769254,src:"https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/94/6c/5b/211769254.jpg",width:480,height:320}]};

    

</script> <script>
	var breadcrumbConfig={breadcrumbAction:"/ajax/breadcrumbController/getLastLevelBreadcrumbGeoAjax.ajax",breadcrumbUrlValue:"/venta-viviendas/cartagena/cartagena/casco-antiguo/",breadcrumbUrlAllMunicipalitiesLevel:"",pageDiscriminatorValue:"listing_home.htm"};
</script> <script type="text/javascript" defer src="https://st1.idealista.com/static/common/release/listing/listing.js?20180704154217"></script> <script type="text/microtemplate" id="login-box-title-fav">
		<span class="icon-fav">
			<span class="txt-bold">Guardar favorito</span>
		</span>
	</script> <script type="text/microtemplate" id="login-box-title-discard">
		<span class="icon-delete">
			<span class="txt-bold">Descartar</span>
		</span>
	</script> <script type="text/microtemplate" id="login-box-title-favfilter">
		<span class="txt-bold">Ver tus favoritos en esta búsqueda</span>
	</script> <script type="text/microtemplate" id="login-box-title-stats">
		<span class="txt-bold">Ver número de visitas y contactos</span>
	</script> <script type="text/microtemplate" id="login-box-content-text-fav">
		<div class="info-txt">
			<p>Crea una lista con los anuncios que te gustan para tenerlos a mano. <br /> Escribe notas personales (solo para ti) para acordarte de los detalles.</p>
			<p>Te avisaremos si alguno de tus favoritos cambia de precio, le añaden fotos o se da de baja.</p>
		</div>
	</script> <script type="text/microtemplate" id="login-box-content-text-discard">
		<div class="info-txt">
			<p>Descarta los anuncios que no te interesan y dejarás de verlos cuando busques.</p>
			<p>Si luego te arrepientes los puedes recuperar desde tus descartados.</p>
		</div>
	</script> <script type="text/microtemplate" id="login-box-content-text-favfilter">
		<div class="info-txt">
			<p>Consulta de forma rápida los favoritos que tienes en cada búsqueda y fíltralos por los criterios que quieras</p>
		</div>
	</script> <script type="text/microtemplate" id="login-box-content-text-stats">
		<div class="info-txt">
			<p>Consulta los datos de popularidad de los anuncios que te interesan: cuántas visitas y contactos han tenido, y cuántas personas lo tienen en sus favoritos</p>
		</div>
	</script> <script type="text/microtemplate" id="login-box-content-tmpl">
		<div class="login-box-form modal-inner"> {{=contentExplanation}} <div id="loginlicker"> <label for="email"> <span class="username initial"> Tu email </span> <span class="username named" style="display:none;" data-username="Hola de nuevo :-)"> </span> <input id="email" class="email" type="email" name="email" autocomplete="email"/> </label> <p class="spinner-inline left"> Comprobando email </p> <label> <span class="username">Tu contraseña</span> <input type="password" class="password" name="pwd"/> </label> <p><a href="/recordar-password" class="forgotpassword">¿Has olvidado tu contraseña?</a></p> <label class="input-checkbox"> <input name="cookie" type="checkbox" checked="checked"/> <span><span>Recordar tus datos</span></span> </label> <label> <span class="msg-repeat"> Por favor, comprueba que tu email está bien escrito </span> <span class="repeat"></span> </label> <label> <span id="msg-accept-privacy-policy"> Tienes que aceptar la política de privacidad para poder continuar </span> </label> <label class="input-checkbox"> <input id="privacy-policy" name="privacy-policy" type="checkbox"/> <span><span>Aceptar la <a href="/info/proteccion-datos" target="_blank">política de privacidad</a></span></span> </label> <label class="input-checkbox"> <input id="subscribe-mailing" name="subscribe-mailing" type="checkbox"/> <span><span>Recibir información de inmuebles, noticias y otras comunicaciones promocionales desde idealista, idealista/data, idealista/hipotecas o Rentalia basadas en tu perfil.</span></span> </label> </div> </div>
	</script> <script type="text/microtemplate" id="login-box-button-initial">
	<div class="modal-inner">
		<a href="#" class="btn regular longer dummy" disabled="disabled">
			¡Vamos!
		</a>
	</div>
	</script> <script type="text/microtemplate" id="login-box-button-fav">
	<div class="modal-inner">
		<a href="#" class="btn action longer accept">
			Guardar favorito
		</a>
	</div>
	</script> <script type="text/microtemplate" id="login-box-button-discard">
	<div class="modal-inner">
		<a href="#" class="btn action longer accept">
			Descartar anuncio
		</a>
	</div>
	</script> <script type="text/microtemplate" id="login-box-button-favfilter">
	<div class="modal-inner">
		<a href="#" class="btn action longer accept">
			Ver sólo favoritos
		</a>
	</div>
	</script> <script type="text/microtemplate" id="login-box-button-stats">
	<div class="modal-inner">
		<a href="#" class="btn action longer accept">
			Ver estadísticas
		</a>
	</div>
	</script> <script type="text/microtemplate" id="login-box-feedback-generic-content">
		<p class="feedback warning icon-feedbk-alert">Sólo falta que confirmes tu email</p>
		<div class="modal-inner">
			<p>Hemos enviado un correo a {{=email}}, no olvides revisar tu correo no deseado, por si acaso ;-)</p>
		</div>
	</script> <script type="text/microtemplate" id="login-box-feedback-generic-buttons">
	<div class="modal-inner">
		<a href="#" class="btn regular longer accept">
			Entendido
		</a>
	</div>
	</script> <script type="text/microtemplate" id="promo-app-title-tmpl">
	<span class="txt-bold">Bájate nuestra app</span>
</script> <script type="text/microtemplate" id="promo-app-content-tmpl">
	
	<img class="promoApp" src="">
	<p>Recibe avisos inmediatos de tus búsquedas y favoritos en cualquier lugar con la app gratuita de idealista</p>
	<div class="download"><a id="buttonDownloadApp" class="btn action txt-bold" data-xiti-markup='{ "click": {"xtPage":"promo-app::download","mustXtn2":true,"actionType":"CLICK"} }' href="http://m.onelink.me/d181dd66">Descargar ahora</a></div>
	<div class="cancel"><a class="buttonCancelDownloadApp" id="buttonCancelDownloadApp" data-xiti-click="promo-app::no-thanks">No, gracias</a></div>
</script> <script>
var configTwoSteps = {
	urls: {
		defaultLogin: "/es/login.ajax",
		defaultPreauthorized: "/es/login-preauthorized.ajax",
		
				
		userStatus: "/check-identification-service-user-status.ajax",
		emailVerifyUrl: "/ajax/alerts-ls-existence-and-active/17"
	},
	userStatus: "" //	authorized, preauthorized, blocked, error
};
</script> <script type="text/microtemplate" id="tsa-confirm-title">
	Verificación de identidad
</script> <script type="text/microtemplate" id="tsa-confirm-send-again-pls">
	<div class="modal-inner">
		<p>¿No lo has recibido o no tienes el móvil contigo?</p>
		<p class="icon-leads"><a href="#" id="sendAgain">Enviar nuevo código al móvil</a></p>
		<p class="icon-phone">
			Ponte en contacto con nuestro equipo llamando al
			<a class="phone" href="tel://902 50 80 00">902 50 80 00</a>
		</p>
		<div class="item-form">
			<label>
				<span>Código de verificación</span>
				<input type="text" id="code_2sa" name="code" data-validation="required" data-message-required="Venga, escribe el código ;-)" />
			</label>
		</div>
	</div>
</script> <script type="text/microtemplate" id="tsa-confirm-content">
	<p class="feedback success icon-feedbk-ok">Hemos enviado un código al {{=phone}}</p> <div class="modal-inner"> <p>Por tu seguridad te recomendamos que antes de continuar compruebes el estado de tu conexión. Para ello deberías ver este <span class="nobreak">icono <img src="https://st1.idealista.com/static/common/release/user-management/resources/img/locker.png"/></span> junto a la dirección web de idealista. </p> </div> <div class="modal-inner"> <div class="item-form"> <label> <span>Código de verificación</span> <input type="text" id="code_2sa" name="code" data-validation="required" data-message-required="Venga, escribe el código ;-)"/> </label> <a href="#" id="resendCode">¿No lo has recibido o no tienes el móvil contigo?</a> </div> </div>
</script> <script type="text/microtemplate" id="tsa-confirm-buttons">
	<div class="modal-inner"> <a href="#" title="Confirmar y entrar" class="btn action accept confirm-btn">Confirmar y entrar</a> </div>
</script> <script type="text/microtemplate" id="tsa-confirm-wrong-code-feedback">
	El código insertado no coincide con el que te hemos enviado.
</script> <script type="text/microtemplate" id="tsa-contactus-title">
	Verificación de identidad
</script> <script type="text/microtemplate" id="tsa-contactus-insistent-feedback">
	Para continuar llama al número que te mostramos y sigue nuestras indicaciones
</script> <script type="text/microtemplate" id="tsa-contactus-content">
	<p class="feedback error icon-feedbk-ko">Parece que estamos teniendo algún problema en validar el código que intentas insertar</p> <div class="modal-inner"> <div class="contactus"> <p> Ponte en contacto con nuestro equipo llamando al <a class="phone" href="tel://902 50 80 00">902 50 80 00</a> y te proporcionaremos un nuevo código de verificación </p> </div> </div>
</script> <script type="text/microtemplate" id="tsa-contactus-buttons">
	<div class="modal-inner"> <a href="#" title="Insertar nuevo código" class="btn regular accept">Insertar nuevo código</a> </div>
</script> <script type="text/microtemplate" id="tsa-contactus-insert-content">
	<div class="modal-inner"> <p>Inserta el código que te hemos facilitado durante la llamada para acceder a tu cuenta</p> </div> <div class="modal-inner"> <div class="item-form"> <label> <span>Código de verificación</span> <input type="text" id="code_2sa" name="code" data-validation="required" data-message-required="Venga, escribe el código ;-)"/> </label> </div> </div>
</script> <script type="text/microtemplate" id="tsa-contactus-insert-buttons">
	<div class="modal-inner"> <a href="#" title="Confirmar y entrar" class="btn action accept confirm-btn">Confirmar y entrar</a> </div>
</script> <script type="text/microtemplate" id="discard-undo-tmpl">
	<div class="feedback contextual full-width success icon-feedbk-ok item-discard-undo" data-adId="{{=id}}">
		<p>Has descartado el anuncio: {{=title}}</p> 
		<a href="#" class="action-discard icon-recover" data-role="remove">Recuperar</a>
	</div>
</script> <script type="text/microtemplate" id="contact-tmpl" data-title="Pregunta al anunciante">
	<div class="modal-inner"> <section class="highlight-content module-contact" contact-modal-type="listing"> <div class="advertiser-info advertiser-info--avatar"> </div> {{showEmailContactMethod}} <form action="" class="form contact" data-service-error='¡Vaya! No hemos podido enviar tu mensaje ¡Prueba otra vez!' novalidate> <div class="item-form"> <label> <span class="contacted"> <p class="contacted"> <span class="icon-mail"> Has contactado <span class="contacted-time"></span> </span> </p> <span class="yourMessage">Tu mensaje fue</span> </span> <textarea placeholder="¿Alguna duda? ¿Quieres visitar el inmueble? ¡Pregunta al anunciante!" name="contact-message" data-message-required="Muestra tu interés escribiendo un mensaje">Hola, me interesa este piso y me gustaría hacer una visita.
Un saludo</textarea> </label> <ul class="last-contact-messages"></ul> </div> <div class="collapsed-form"> <div class="item-form"> <label> <span>Tu email</span> <input name="contact-email" type="email" class="js-email-field" value="" data-validation="email" autocomplete="email" data-message-email='Revisa el formato de tu email' data-required-group="contact-data" data-contact-data-error='Indica un email o teléfono para que te puedan contestar ;-)'> </label> </div> <div class="item-form half-items clearfix"> <div> <label> <span>Tu teléfono</span> <input name="contact-phone" type="tel" value="" autocomplete="tel" data-validation="phone" data-message-phone='Revisa tu teléfono' data-required-group="contact-data"> </label> </div> <div> <label> <span>Tu nombre</span> <input name="contact-name" type="text" autocomplete="name" data-validation="name" value="" data-message-required="Indica tu nombre " data-message-name="Esto no parece un nombre"> </label> </div> </div> <span class="general-errors-container feedback contextual full-width warning icon-feedbk-alert d-none"></span> <span class="service-error-container feedback contextual full-width error icon-feedbk-ko d-none"></span> {{showFavoriteCheck}} <div class="item-form contact-fav-container"> <label class="input-checkbox"> <input type="checkbox" name="contact-fav" checked> <span><span>Guardar en tus favoritos</span></span> </label> </div> {{/showFavoriteCheck}} <div class="captcha-miniFields d-none" data-service-prefix=""> <div class="captcha"> <div class="captcha-img"> </div> </div> <div class="item-form half-items clearfix"> <label> <span>Escribe los números y letras que ves arriba</span> <div> <input type="text" class="_captcha" name="contact-captcha" autocapitalize="none" autocorrect="off"/> </div> </label> <p><a class="captcha-reload" href="#">¿No entiendes lo que pone?</a></p> </div> </div> <div id="privacy-policy-detail" class="item-form privacy-policy-container"> <label class="input-checkbox" data-validation="checkbox" data-message-checkbox="Para contactar debes aceptar la política de privacidad"> <input type="checkbox" name="privacy-policy-checkbox"/> <span><span> Aceptar <a href="/info/proteccion-datos" target="_blank">política de privacidad</a> </span></span> </label> </div> <input type="hidden" name="adId" value="{{=adId}}"/> <input type="hidden" name="operationId" value="1"> <input type="hidden" name="type" id="contact-type" value=""/> </div> <div class="d-none"> <input type="text" value="" name="contact-mail"> </div> <div> <input type="submit" class="btn action txt-bold txt-big" value="Contactar" data-xiti-shared-n2=true data-xiti-page="listado::conversiones::form_contacto" data-contacted="Contactar de nuevo"/> </div> </form> <div class="feedback-container d-none"></div> {{:showEmailContactMethod}} <span class="txt-soft no-contact-form"> El anunciante prefiere ser contactado solo por teléfono. </span> {{/showEmailContactMethod}} <div class="advertiser-info-footer"> </div> </section> </div>
</script> <script type="text/microtemplate" id="contact-feedback-tmpl">
	<div class="contextual success icon-feedbk-ok"> {{normalMessage}} ¡Genial! mensaje enviado {{:normalMessage}} mensaje enviado a las inmobliarias {{/normalMessage}} {{showRepeat}} <a href="#" class="repeat-contact" data-xiti-page=""> Volver a contactar </a> {{/showRepeat}} </div> {{saveAlert}} <div> <p class="text-save-search"> Guarda tu búsqueda para recibir por email nuevos anuncios similares a este </p> <a href="#" class="btn action expand txt-bold txt-big save-search" title='Guardar búsqueda' data-summaryurl="/recibir-alertas-gratis-primer-resumen/23" data-saveurl="/savealert.ajax/19" data-saverelatedurl="/ajax/save-related-alert-popup.ajax/28" data-emailverifyurl="/ajax/alerts-ls-existence-and-active/17" data-forgotpasswordurl="/recordar-password" data-didntgetmailurl="/info/info-problema-email"> Guardar búsqueda </a> {{/saveAlert}} {{suggestAgencies}} <p> Estas inmobiliarias te pueden ayudar a buscar inmuebles similares </p> <ul> {{@suggestedAgencies}} <li> <input type="checkbox" id="suggest_inmo_{{=_key}}" data-inmo-id="{{=_val.commercialDataId}}" checked/> <label for="suggest_inmo_{{=_key}}"> {{=_val.commercialName}} </label> </li> {{/@suggestedAgencies}} </ul> <a href="#" class="btn regular contact-pro expand" title='Contactar agencias'> Contactar agencias </a> {{/suggestAgencies}} </div>
</script> <script type="text/microtemplate" id="change-operation-tmpl" data-modal-title="¿Qué buscas?">
	<form name="#" action="/listing_home.htm/listingDispatcherController" method="post" id="change-operation-typology"> <div id="operation-mobile"> <ul class="segmented-btn-group clearfix"> <li> <a href="#" data-value="1" rel="nofollow" class="btn regular smaller selected"> Comprar </a> </li> <li> <a href="#" data-value="2" rel="nofollow" class="btn regular smaller"> Alquilar </a> </li> <li> <a href="#" data-value="share" rel="nofollow" class="btn regular smaller"> Compartir </a> </li> </ul> </div> <div id="typology-mobile" class="item-form"> <ul> <li> <label class="input-radio"> <input name="typology" value="10" type="radio"> <span><span>Obra nueva</span></span> </label> </li> <li> <label class="input-radio"> <input name="typology" value="1" type="radio" checked="checked"> <span> <span>Viviendas</span></span> </label> </li> <li> <label class="input-radio"> <input name="typology" value="7" type="radio"> <span> <span>Habitación</span></span> </label> </li> <li> <label class="input-radio"> <input name="typology" value="5" type="radio"> <span> <span>Oficinas</span> </span> </label> </li> <li> <label class="input-radio"> <input name="typology" value="6" type="radio"> <span> <span>Locales o naves</span> </span> </label> </li> <li> <label class="input-radio"> <input name="typology" value="4" type="radio"> <span> <span>Garajes</span> </span> </label> </li> <li> <label class="input-radio"> <input name="typology" value="8" type="radio"> <span> <span>Terrenos</span> </span> </label> </li> <li> <label class="input-radio"> <input name="typology" value="12" type="radio"> <span> <span>Trasteros</span> </span> </label> </li> <li> <label class="input-radio"> <input name="typology" value="13" type="radio"> <span> <span>Edificios</span> </span> </label> </li> </ul> </div> <input type="hidden" name="operation" value="1"/> <input type="hidden" name="locationUri" value="cartagena/cartagena/casco-antiguo"/> <input type="submit" id="change-operation-mobile-btn" class="btn action" value="Buscar"/> </form>
</script> <script type="text/microtemplate" id="listing-loading-tmpl">
	<div class="listing-loading"> <div class="listing-loading-content"> <div class="listing-loading-image"> <img src="https://st1.idealista.com/static/common/release/modules/resources/img/id-spinner2.gif?20180704154217"> </div> <div class="listing-loading-text"> <p>Buscando...</p> </div> </div> </div>
</script> <script type="text/microtemplate" id="custom-slide-end">
	<img class="back-picture"></img> <div class="custom-slide"> <p class="custom-slide-message"> ¿Te ha gustado? </p> <a class="btn action custom-slide-contact">Contactar</a> <a class="custom-slide-detail">Ver detalles y fotos grandes</a> </div>
</script> <script type="text/microtemplate" id="save-live-search-error">
	<div id="content"> <div class="feedback warning"> {{@errorMessages}}<span>{{=_val}}<span></br>{{/@errorMessages}} </div> </div> <div id="buttons"> <a href="#" class="btn action cancel">Cerrar</a> <div>
</script> <script type="text/microtemplate" id="expert-card-tpl">
    <div class="expert-card card-{{=idx}}" data-commercialdataid="{{=commercialDataId}}">
        <div class="head">
            <div class="expert-multimedia">
                <div class="image-holder">
                    {{hasImage}}
                    <img src="{{=headImageUrl}}" crossorigin="anonymous" />
                    {{/hasImage}}
                </div>
            </div>
        </div><div class="info-container">
            <div class="centrable">
                <div class="agency-logo">
                    <img src="{{=logoUrl}}"/>
                </div>
                <h4 class="agency-link">
                    <a class="item-link" href="{{=agencyUrl}}" title="">{{=agencyName}}</a>
                </h4>
            </div>

            <p class="expert-detail stamps">
                {{showTMs}}
                    <span>Miembro de: </span>
                    {{@trademarks}}
                        <img src="{{=_val.url}}" class="stamp" />
                    {{/@trademarks}}
                    {{hasLicenseCode}}
                        <span class="license-code-num">{{=licenseCode}}</span>
                    {{/hasLicenseCode}}
                {{:showTMs}}
                    &nbsp;
                {{/showTMs}}
            </p>
                
            <p class="expert-detail">
                {{showTotal}}
                    {{=total}} inmuebles en idealista
                {{:showTotal}}
                    &nbsp;
                {{/showTotal}}
            </p>


            <p class="expert-detail">
                {{showYears}}
                    {{=years}} años en idealista
                {{:showYears}}
                    &nbsp;
                {{/showYears}}
            </p>


            <p class="expert-detail karma karma-{{=karma}}">
                <span class="blob score-1"></span><span class="blob score-2"></span><span class="blob score-3"></span><span class="blob score-4"></span><span class="blob score-5"></span>
            </p>

        </div>
        <div class="contact-container">
            <a class="icon-mail js-contact">Valorar gratis tu inmueble</a>
        </div>
    </div>
</script> <script type="text/microtemplate" id="expert-card-compact-tpl">
    <div class="expert-card compact card-{{=idx}}" data-commercialdataid="{{=commercialDataId}}">
        <a class="link-wrap" href="{{=agencyUrl}}" title="{{=agencyName}}">
        <div class="head">
            <div class="expert-multimedia">
                <div class="image-holder">
                </div>
            </div>
        </div><div class="info-container">
            <div class="centrable">
                <div class="agency-logo">
                    <img src="{{=logoUrl}}" crossorigin="anonymous" />
                </div>
                <h4 class="agency-link">
                    <a class="item-link" href="{{=agencyUrl}}" title="{{=agencyName}}">{{=agencyName}}</a>
                </h4>
            </div>
            <div class="details">

            {{showTotal}}
                <p class="expert-detail centrable">{{=total}} inmuebles en idealista</p>
            {{/showTotal}}

            {{showYears}}
                <p class="expert-detail centrable">{{=years}} años en idealista</p>
            {{/showYears}}
            </div>
        </div>
        </a>
    </div>
</script> <script type="text/microtemplate" id="advertiser-info-header-content">


    
        {{avatarUrl}}
            <img src="{{=avatarUrl}}"/>
        {{/avatarUrl}}
    


    {{isAdProfessionalAndAgencyIsNotABank}}
        <div class="advertiser-container">
            <p class="advertiser-name">
                {{showAdvertiserName}}
                    {{firstName}}
                        {{=firstName}} {{=lastName}}
                    {{/firstName}}
                {{/showAdvertiserName}}
            </p>
        {{:isAdProfessionalAndAgencyIsNotABank}}
          <div class="advertiser-container">
            <p class="advertiser-name__costumer">
                {{firstName}}
                    {{isInvoiceAd}}
                        {{=firstName}}
                    {{:isInvoiceAd}}
                        <strong>{{=firstName}}</strong>
                    {{/isInvoiceAd}}
                {{/firstName}}
            </p>
        {{/isAdProfessionalAndAgencyIsNotABank}}

        <div class="shortAdDescription">
            <p class="ellipsis">{{=shortDescription}}</p>
        </div>
      </div>
    </div>
</script> <script type="text/microtemplate" id="advertiser-info-footer-content">

    
    <div class="advertiser-data">
        
        {{showPhoneContactMethod}}
        <div class="{{=contactPhoneClass}}">
            {{formattedContactPhone1}}
            <div class="phone first-phone">
                <p class="txt-bold _browserPhone icon-phone">
                    
                        
                        
                            {{=formattedContactPhone1}}
                        
                    
                </p>
            </div>
            {{/formattedContactPhone1}}

            {{showFormattedContactPhone2}}
            <div class="phone last-phone">
                <p class="txt-bold _browserPhone icon-phone">
                    
                        
                        
                            {{=formattedContactPhone2}}
                        
                    
                </p>
            </div>
            {{/showFormattedContactPhone2}}
        </div>
        {{:showPhoneContactMethod}}
        <div class="contact-phones">
            <div class="phone hide-phone">
                El anunciante prefiere ser contactado solo por correo.
            </div>
        </div>
        {{/showPhoneContactMethod}}

        
        {{newDevelopmentDirectory}}
            <div class="new-dev-directory-message">
                <div class="new-dev-directory-message">Ten a mano el código {0} al llamar</div>
            </div>
        {{/newDevelopmentDirectory}}
    </div>

    <div class="module-contact-gray">
        
        {{agencyIsABank}}
            <strong>{{=adTypologyName}} de banco</strong>
        {{:agencyIsABank}}
            {{isAdProfessional}}
                <p class="professional-name">
                    Profesional
                    {{showProfessionalName}}
                        {{firstName}}
                            - {{=firstName}} {{=lastName}}
                        {{:firstName}}
                            - {{=commercialName}}
                        {{/firstName}}
                    {{/showProfessionalName}}
                </p>
            {{:isAdProfessional}}
                <p class="txt-ref">
                    {{firstName}}
                        {{isInvoiceAd}}
                            <!-- Si, es feo, Se hace de esta forma ya que si no devuelve un "undefined" con {{!isInvoiceAd}}...  -->
                        {{:isInvoiceAd}}
                            Particular -
                        {{/isInvoiceAd}}
                        {{=firstName}}
                    {{/firstName}}
                </p>
            {{/isAdProfessional}}
        {{/agencyIsABank}}

        <p>
            {{=referenceMessage}}
        </p>

        
        {{showAboutAdvertiser}}
            <div class="advertiser-name-container">
                {{isVirtualMicrosite}}
                    <p class="about-advertiser-name" >
                        {{=commercialNamePhraseBlock}}
                    </p>
                {{:isVirtualMicrosite}}
                    <a class="about-advertiser-name" href="{{=advertiserNameLink}}" title="{{=commercialNamePhraseBlock}}">
                        {{=commercialNamePhraseBlock}}
                    </a>
                {{/isVirtualMicrosite}}

                <p class="advertiser-name-location">{{=micrositeCityName}}</p>
            </div>

            
            <div class="about-advertiser">
                {{mustShowLogo}}
                <div class="advertiser-logo">
                    <a href="{{=advertiserNameLink}}">
                        <img src="{{=advertiserLogoUrl}}"
                             data-ondemand-img="{{=advertiserLogoUrl}}"
                             width="125"
                             height="60"
                             alt="{{=commercialNamePhraseBlock}}" />
                    </a>
                </div>
                {{/mustShowLogo}}
            </div>
        {{/showAboutAdvertiser}}
    </div>
</script> <script type="text/javascript" async src="https://st1.idealista.com/static/common/js/criteo/ld.js?20180704154217"></script> <script type="text/javascript">
						<!--
						xtnv = document; 
						xtsd = "https://logs3";
						xtsite =  "352991";
						xtdmc = ".idealista.com";
						xtn2 = "2";
						xtpage = "listado::listado-resultados::www.idealista.com/venta-viviendas/cartagena/cartagena/casco-antiguo/";
						xtdi = "0";
						xt_multc = "";
						xt_orderid = "";
						xt_roimt = "";
						xt_an = "anonymous";
						xt_ac = "2";
						clic = "#clic#";			
						xt_tags = "[listado_1]";
				    if (window.xtparam != null) {
				        window.xtparam += "&tag=" + xt_tags;
				    } else {
				        window.xtparam = "&tag=" + xt_tags;
				    };
						if (window.xtparam!=null) {
							window.xtparam+="&cmd="+xt_orderid+"&an="+xt_an+"&ac="+xt_ac+"&roimt="+xt_roimt+xt_multc;
						} else {
							window.xtparam="&cmd="+xt_orderid+"&an="+xt_an+"&ac="+xt_ac+"&roimt="+xt_roimt+xt_multc;
						};
						//-->
					</script> <noscript> <img width="1" height="1" src="https://logs3.xiti.com/hit.xiti?s=352991&s2=2&p=listado::listado-resultados::www.idealista.com/venta-viviendas/cartagena/cartagena/casco-antiguo/&di=0&x19=[]&cmd=&xt_an=anonymous&xt_ac=2&roimt=&clic=#clic#"> </noscript><script type='text/javascript' src='https://st1.idealista.com/static/common/js/ext/xiti/xiti.js' async></script> <script type="text/javascript">
	var utag_data = {"page":{"section":"portal","subsection":"listing","name":"","language":"es","operation":"1","typology":"1","markup":{"category":"","subCategory":"","subSubCategory":"","xtPage":"listado::listado-resultados::www.idealista.com/venta-viviendas/cartagena/cartagena/casco-antiguo/"}},"user":{"status":"2","type":"","id":"","commercialDataId":"","languageCommunication":"","search":{"operation":"1","typology":"1","geo":""}},"response":{"statusCode":"200","webServer":"","loadBalancer":"web","errorTemplate":""}};
	var toggleTealiumClicks = false
</script> <script type="text/javascript">
	(function(a,b,c,d){
	a='//tags.tiqcdn.com/utag/idealista/es-portal/prod/utag.js';
	b=document;c='script';d=b.createElement(c);d.src=a;d.type='text/java'+c;d.async=true;
	a=b.getElementsByTagName(c)[0];a.parentNode.insertBefore(d,a);
	})();
</script> <script type="text/javascript" src="https://st1.idealista.com/static/common/js/criteo/ld.js?20180704154217" async="true"></script> <script type="text/javascript">
							window.criteo_q = window.criteo_q || [];
							window.criteo_q.push(
								{ event: "setAccount", account: [13122, 19089, 31531] },
								{ event: "setCustomerId", id: "" },
								{ event: "setSiteType", type: "d" },
								{ event: "viewList", item: ["81564623","81261953","81469320"], keywords: "casas y pisos  en Casco Antiguo, Cartagena", user_segment: "1" }
							);
						</script> </body> </html>
"""

# %%
from bs4 import BeautifulSoup
html=BeautifulSoup(contenido,"html.parser")

# %%
listaPisos=html.findAll(class_="item-info-container")

# %%
listaPisos[2].find(class_="item-price h2-simulated").text
# Out:
# '199.000€'

# %%
pisos=[]
for piso in listaPisos:
    precio=piso.find(class_="item-price h2-simulated").text.replace(".","").replace("€","")
    caracteristicas=piso.findAll(class_="item-detail")
    habitaciones=caracteristicas[0].text.replace("hab.","").strip()
    superficie=caracteristicas[1].text.replace("m²","").strip()
    if habitaciones.isnumeric() and superficie.isnumeric():    
        #print(precio,habitaciones,superficie)
        pisos.append((int(precio),
                      int(habitaciones),
                      int(superficie)))

# %%
pisosDF=spark.createDataFrame(pisos,["Precio","Habitaciones","m2"])

# %%
pisosDF.printSchema(),pisosDF.show()
# Out:
# root
#  |-- Precio: long (nullable = true)
#  |-- Habitaciones: long (nullable = true)
#  |-- m2: long (nullable = true)
#
# +------+------------+---+
# |Precio|Habitaciones| m2|
# +------+------------+---+
# |399000|           4|231|
# |248900|           4|191|
# |199000|           4|199|
# |240000|           3|128|
# |285000|           3|103|
# |229000|           3|111|
# |300000|           5|218|
# |215000|           5|163|
# |124500|           2| 79|
# |110000|           4|100|
# |110000|           4|100|
# |297000|           3| 91|
# |255000|           4|206|
# |250000|           3| 85|
# |110000|           1| 59|
# |227000|           2| 83|
# |182000|           3|100|
# |360000|           4|147|
# |139000|           3|108|
# |120000|           4|130|
# +------+------------+---+
# only showing top 20 rows
# (None, None)

# %%
pisosDF.summary().show(vertical=True)
# Out:
# -RECORD 0--------------------------
#  summary      | count
#  Precio       | 29
#  Habitaciones | 29
#  m2           | 29
# -RECORD 1--------------------------
#  summary      | mean
#  Precio       | 217772.41379310345
#  Habitaciones | 3.413793103448276
#  m2           | 131.86206896551724
# -RECORD 2--------------------------
#  summary      | stddev
#  Precio       | 83033.03084810684
#  Habitaciones | 1.0861873483267168
#  m2           | 50.49450050531037
# -RECORD 3--------------------------
#  summary      | min
#  Precio       | 110000
#  Habitaciones | 1
#  m2           | 59
# -RECORD 4--------------------------
#  summary      | 25%
#  Precio       | 145000
#  Habitaciones | 3
#  m2           | 100
# -RECORD 5--------------------------
#  summary      | 50%
#  Precio       | 227000
#  Habitaciones | 3
#  m2           | 111
# -RECORD 6--------------------------
#  summary      | 75%
#  Precio       | 280000
#  Habitaciones | 4
#  m2           | 163
# ...

# %%
pisosP=pisosDF.toPandas()
pisosP.boxplot("Precio")

# %%
pisosP.boxplot("Habitaciones")

# %%
pisosP.boxplot("m2")

# %%
from pandas.plotting import scatter_matrix

a=scatter_matrix(pisosP,figsize=(6,6))

# %%
from pyspark.ml.regression import LinearRegression
from pyspark.ml.feature import VectorAssembler

# %%
constructor=VectorAssembler(inputCols=["Habitaciones","m2"],outputCol="features")

# %%
pisosFinal=constructor.transform(pisosDF)

# %%
pisosFinal.show()
# Out:
# +------+------------+---+-----------+
# |Precio|Habitaciones| m2|   features|
# +------+------------+---+-----------+
# |399000|           4|231|[4.0,231.0]|
# |248900|           4|191|[4.0,191.0]|
# |199000|           4|199|[4.0,199.0]|
# |240000|           3|128|[3.0,128.0]|
# |285000|           3|103|[3.0,103.0]|
# |229000|           3|111|[3.0,111.0]|
# |300000|           5|218|[5.0,218.0]|
# |215000|           5|163|[5.0,163.0]|
# |124500|           2| 79| [2.0,79.0]|
# |110000|           4|100|[4.0,100.0]|
# |110000|           4|100|[4.0,100.0]|
# |297000|           3| 91| [3.0,91.0]|
# |255000|           4|206|[4.0,206.0]|
# |250000|           3| 85| [3.0,85.0]|
# |110000|           1| 59| [1.0,59.0]|
# |227000|           2| 83| [2.0,83.0]|
# |182000|           3|100|[3.0,100.0]|
# |360000|           4|147|[4.0,147.0]|
# |139000|           3|108|[3.0,108.0]|
# |120000|           4|130|[4.0,130.0]|
# +------+------------+---+-----------+
# only showing top 20 rows

# %%
lr=LinearRegression(labelCol="Precio")

# %%
modelo=lr.fit(pisosFinal)

# %%
modelo.summary.r2
# Out:
# 0.41777682289493334

# %%
nuevo=spark.createDataFrame([(3,100)],["Habitaciones","m2"])
nuevoF=constructor.transform(nuevo)
modelo.transform(nuevoF).show()
# Out:
# +------------+---+-----------+------------------+
# |Habitaciones| m2|   features|        prediction|
# +------------+---+-----------+------------------+
# |           3|100|[3.0,100.0]|182312.95829357434|
# +------------+---+-----------+------------------+

# %%
h=input("Habitaciones: ")
m=input("m2: ")

nuevo=spark.createDataFrame([(int(h),int(m))],["Habitaciones","m2"])
nuevoF=constructor.transform(nuevo)
modelo.transform(nuevoF).show()
# Out:
# Habitaciones: 3
# m2: 120
# +------------+---+-----------+-----------------+
# |Habitaciones| m2|   features|       prediction|
# +------------+---+-----------+-----------------+
# |           3|120|[3.0,120.0]|210263.3808781727|
# +------------+---+-----------+-----------------+
